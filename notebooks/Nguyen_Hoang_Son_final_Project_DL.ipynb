# %% [markdown]
# # Import Library

# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize
from IPython.display import clear_output
from matplotlib.pyplot import imshow
import pandas as pd
from sklearn.model_selection import train_test_split
import datetime
import torch
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchinfo import summary
from tqdm import tqdm
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2
from torchvision.transforms import ToTensor
import wandb
from sklearn.metrics import confusion_matrix
import random
import os
from sklearn.preprocessing import OneHotEncoder
from torchvision import transforms
# Out:
# /opt/conda/lib/python3.10/site-packages/albumentations/__init__.py:24: UserWarning: A new version of Albumentations is available: 1.4.22 (you have 1.4.21). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()

# %%
import kagglehub

path = kagglehub.dataset_download("pypiahmad/realistic-action-recognition-ucf50-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/realistic-action-recognition-ucf50-dataset

# %%
output_file = "/kaggle/working/train.txt"
ucf11 = r"/kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg"
ucf101 = "/kaggle/input/ucf101/UCF101"
with open(output_file, "w") as f:
    x = -1
    for action_folder in os.listdir(ucf11):
        action_folder_path = os.path.join(ucf11, action_folder)
        x +=1
        if os.path.isdir(action_folder_path):
            print(action_folder_path)
            for group_folder in os.listdir(action_folder_path):
                
                group_folder_path = os.path.join(action_folder_path, group_folder)
                
                if os.path.isdir(group_folder_path):
                    # Duyệt qua các video trong nhóm
                    for video_file in os.listdir(group_folder_path):
                        video_file_path = os.path.join(group_folder_path, video_file)
                        if video_file.endswith(".mpg") or video_file.endswith(".avi"):
                            f.write(f"{video_file_path} {x}\n")
# Out:
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/biking
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/trampoline_jumping
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/swing
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/walking
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/golf_swing
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/soccer_juggling
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/tennis_swing
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/volleyball_spiking
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/basketball
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/horse_riding
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg/diving

# %%
train_df = pd.read_csv("train.txt",sep = " ",header = None,names = ['path','class'])
train_df['path'] = train_df['path'].str.replace(ucf11, '', regex=False).str.lstrip("\\")
train_df
# Out:
#                                         path  class
# 0     /biking/v_biking_05/v_biking_05_05.mpg      0
# 1     /biking/v_biking_05/v_biking_05_04.mpg      0
# 2     /biking/v_biking_05/v_biking_05_08.mpg      0
# 3     /biking/v_biking_05/v_biking_05_01.mpg      0
# 4     /biking/v_biking_05/v_biking_05_02.mpg      0
# ...                                      ...    ...
# 1595  /diving/v_diving_21/v_diving_21_02.mpg     10
# 1596  /diving/v_diving_18/v_diving_18_04.mpg     10
# 1597  /diving/v_diving_18/v_diving_18_01.mpg     10
# 1598  /diving/v_diving_18/v_diving_18_03.mpg     10
# 1599  /diving/v_diving_18/v_diving_18_02.mpg     10
#
# [1600 rows x 2 columns]

# %%
class_counts = train_df['class'].value_counts()
print(class_counts)
# Out:
# class
# 9     198
# 6     167
# 10    156
# 5     156
# 0     145
# 4     142
# 8     141
# 2     137
# 3     123
# 1     119
# 7     116
# Name: count, dtype: int64

# %%
def prepareData2(video_path, _resize, num_classes, num_frames):
    content = []
    
    for i in range(6,num_classes):
        df_temp = train_df[train_df['class'] == i]  
        if not df_temp.empty: 
            path = df_temp['path'].tolist() 
            content.extend(path) 
        else:
            print(f"Class {i} fail")

    if len(content) == 0:
        raise ValueError("None video found!")

    content = np.array(content) 
    videos = []

    for j in range(len(content)):
        print(f"Processing {np.round(100 * j / len(content), 3)}%: {content[j]}")
        x = video_path + '/' + content[j]
        vcap = cv2.VideoCapture(x)
        total_frames = int(vcap.get(cv2.CAP_PROP_FRAME_COUNT))

        if total_frames < num_frames:
            print("total frames < num frames")
            selected_indices = range(total_frames)  
        else:
            selected_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)  

        frames = []
        count = 0
        success = True
        while success:
            success, image = vcap.read()
            if not success:
                break
            if count in selected_indices:
                try:
                    image = resize(image, _resize)  
                    frames.append(image)
                except Exception as e:
                    print(f"Error in frame {count} in video {content[j]}: {e}")
            count += 1

        if len(frames) == num_frames: 
            videos.append(frames)
        else:
            print(f"Video {content[j]} not enough frame")

        vcap.release()
    videos = np.array(videos)
    print(f"Shape của videos: {videos.shape}")

    y = []
    for i in range(6, num_classes):
        count_videos = len(train_df[train_df['class'] == i])
        y.extend([i] * count_videos)
    y = np.array(y[:len(videos)]) 
    print(f"Shape của labels: {y.shape}")
    return videos, y

# %%
def prepareData(video_path, _resize, num_classes, num_frames):
    content = []
    
    for i in range(num_classes):
        df_temp = train_df[train_df['class'] == i]  
        if not df_temp.empty: 
            path = df_temp['path'].tolist() 
            content.extend(path)  
        else:
            print(f"Class {i} fail")

    content = np.array(content)  
    videos = []

    for j in range(len(content)):
        
        print(np.round(100 * j / len(content), 3))
        x = video_path + '/' + content[j]
        print(x)
        vcap = cv2.VideoCapture(x)
        total_frames = int(vcap.get(cv2.CAP_PROP_FRAME_COUNT))
        selected_indices = np.linspace(0, total_frames - 1, num_frames, dtype=int)
        success = True

        frames = []
        count = 0
        while success:
            try:
                success, image = vcap.read()
                count += 1
                if count in selected_indices:
                    print(image.shape)
                    image = resize(image, _resize)
                    print(image.shape)
                    frames.append(image)
                    print(f"Number of images per frame: {len(frames)}")
            except Exception as e:
                print(e)

        videos.append(frames)
        print(f"Number of videos: {len(videos)}")
    vcap.release()

    videos = np.array(videos)
    print(videos.shape)
    videos = videos.reshape((videos.shape[0], 3, videos.shape[1], videos.shape[2], videos.shape[3]))

    y = np.array([i for i in range(num_classes) for _ in range(len(train_df[train_df['class'] == i]))])
    y = y.reshape(-1)
    print(y.shape)
    return videos, y

# %%
VIDEO_PATH = ucf11
RESIZE = (64,64)
NUM_CLASSES = 101
NUM_FRAMES = 17
BATCH_SIZE = 16
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Using device: {DEVICE}")
# Out:
# Using device: cuda

# %%
class PrepareData(Dataset):
    def __init__(self, data, target, transform=None):
        self.data = data
        self.target = target
        self.transform = transform
        self.target = target

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        data = self.data[index]
        target = self.target[index]
    
        if isinstance(data, torch.Tensor):
            data = data.numpy()
        elif not isinstance(data, np.ndarray):
            data = np.array(data)
    
        data = torch.tensor(data, dtype=torch.float)
    
        if self.transform:
            data = self.transform(data) 
        data = data.squeeze()
        return data, target

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
secret_value_0 = user_secrets.get_secret("wandb_api_key")

# %%
import wandb
wandb.login(key=secret_value_0)
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
wandb.init(
    project = "Project_DL"
)
# Out:
# wandb: Currently logged in as: nguyenhoangson_hsgs19 (nguyenhoangson_hsgs19-hanoi-university-of-science-and-te). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/kaggle/working/wandb/run-20241210_054124-on9xvsv1</code>
# Syncing run <strong><a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/on9xvsv1' target="_blank">volcanic-hill-32</a></strong> to <a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL' target="_blank">https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL</a>
#  View run at <a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/on9xvsv1' target="_blank">https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/on9xvsv1</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/on9xvsv1?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %% [markdown]
# # Prepare Data

# %%
data1, targets1 = prepareData(video_path=VIDEO_PATH,
                            _resize=RESIZE,
                            num_classes=6,
                            num_frames=NUM_FRAMES)
# Out:
# 0.0
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_05/v_biking_05_05.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 1
# 0.122
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_05/v_biking_05_04.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 2
# 0.243
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_05/v_biking_05_08.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 3
# 0.365
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_05/v_biking_05_01.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 4
# 0.487
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_05/v_biking_05_02.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 5
# 0.608
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_05/v_biking_05_03.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 6
# 0.73
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_05/v_biking_05_07.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 7
# 0.852
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_05/v_biking_05_09.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 8
# 0.973
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_05/v_biking_05_06.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 9
# 1.095
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_17/v_biking_17_03.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 10
# 1.217
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_17/v_biking_17_05.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 11
# 1.338
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_17/v_biking_17_06.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 12
# 1.46
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_17/v_biking_17_02.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 13
# 1.582
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_17/v_biking_17_04.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 14
# 1.703
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_17/v_biking_17_01.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 15
# 1.825
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_15/v_biking_15_01.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 16
# 1.946
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_15/v_biking_15_02.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 17
# 2.068
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_15/v_biking_15_04.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 18
# 2.19
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_15/v_biking_15_03.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 19
# 2.311
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_15/v_biking_15_05.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 20
# 2.433
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_16/v_biking_16_01.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 21
# 2.555
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_16/v_biking_16_03.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 22
# 2.676
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_16/v_biking_16_04.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 23
# 2.798
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_16/v_biking_16_05.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 24
# 2.92
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_16/v_biking_16_02.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 25
# 3.041
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_03/v_biking_03_01.mpg
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 26
# 3.163
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_03/v_biking_03_03.mpg
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 27
# 3.285
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_03/v_biking_03_04.mpg
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 28
# 3.406
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_03/v_biking_03_02.mpg
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 29
# 3.528
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_10/v_biking_10_01.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 30
# 3.65
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_10/v_biking_10_03.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 31
# 3.771
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_10/v_biking_10_05.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 32
# 3.893
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_10/v_biking_10_06.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 33
# 4.015
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_10/v_biking_10_04.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 34
# 4.136
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_10/v_biking_10_02.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 35
# 4.258
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_14/v_biking_14_02.mpg
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 36
# 4.38
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_14/v_biking_14_04.mpg
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 37
# 4.501
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_14/v_biking_14_01.mpg
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 38
# 4.623
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_14/v_biking_14_03.mpg
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (239, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 39
# 4.745
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_09/v_biking_09_04.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 40
# 4.866
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_09/v_biking_09_02.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 41
# 4.988
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_09/v_biking_09_01.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 42
# 5.109
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_09/v_biking_09_03.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 43
# 5.231
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_22/v_biking_22_01.mpg
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (262, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 44
# 5.353
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_22/v_biking_22_05.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 45
# 5.474
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//biking/v_biking_22/v_biking_22_04.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# ...
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 807
# 98.175
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_24/v_juggle_24_01.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 808
# 98.297
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_18/v_juggle_18_01.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 809
# 98.418
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_18/v_juggle_18_07.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 810
# 98.54
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_18/v_juggle_18_06.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 811
# 98.662
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_18/v_juggle_18_04.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 812
# 98.783
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_18/v_juggle_18_08.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 813
# 98.905
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_18/v_juggle_18_02.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 814
# 99.027
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_18/v_juggle_18_05.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 815
# 99.148
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_18/v_juggle_18_03.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 816
# 99.27
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_12/v_juggle_12_05.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 817
# 99.392
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_12/v_juggle_12_06.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 818
# 99.513
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_12/v_juggle_12_03.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 819
# 99.635
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_12/v_juggle_12_01.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 820
# 99.757
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_12/v_juggle_12_02.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 821
# 99.878
# /kaggle/input/realistic-action-recognition-ucf50-dataset/UCF11_updated_mpg//soccer_juggling/v_juggle_12/v_juggle_12_04.mpg
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 1
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 2
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 3
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 4
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 5
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 6
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 7
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 8
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 9
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 10
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 11
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 12
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 13
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 14
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 15
# (240, 320, 3)
# (64, 64, 3)
# Number of images per frame: 16
# Number of videos: 822
# (822, 16, 64, 64, 3)
# (822,)

# %%
print(data1.shape)
print(targets1.shape)
# Out:
# (822, 3, 16, 64, 64)
# (822,)

# %%
# np.save('/kaggle/working/data1.npy', data1)  
# np.save('/kaggle/working/targets1.npy', targets1)

# %%
data2, targets2 = prepareData2(video_path=VIDEO_PATH,
                            _resize=RESIZE,
                            num_classes=11,
                            num_frames=16)
# Out:
# Processing 0.0%: /tennis_swing/v_tennis_14/v_tennis_14_05.mpg
# Processing 0.129%: /tennis_swing/v_tennis_14/v_tennis_14_06.mpg
# Processing 0.257%: /tennis_swing/v_tennis_14/v_tennis_14_02.mpg
# Processing 0.386%: /tennis_swing/v_tennis_14/v_tennis_14_03.mpg
# Processing 0.514%: /tennis_swing/v_tennis_14/v_tennis_14_07.mpg
# Processing 0.643%: /tennis_swing/v_tennis_14/v_tennis_14_04.mpg
# Processing 0.771%: /tennis_swing/v_tennis_14/v_tennis_14_01.mpg
# Processing 0.9%: /tennis_swing/v_tennis_05/v_tennis_05_05.mpg
# Processing 1.028%: /tennis_swing/v_tennis_05/v_tennis_05_06.mpg
# Processing 1.157%: /tennis_swing/v_tennis_05/v_tennis_05_07.mpg
# Processing 1.285%: /tennis_swing/v_tennis_05/v_tennis_05_04.mpg
# Processing 1.414%: /tennis_swing/v_tennis_05/v_tennis_05_02.mpg
# Processing 1.542%: /tennis_swing/v_tennis_05/v_tennis_05_03.mpg
# Processing 1.671%: /tennis_swing/v_tennis_05/v_tennis_05_01.mpg
# Processing 1.799%: /tennis_swing/v_tennis_23/v_tennis_23_05.mpg
# Processing 1.928%: /tennis_swing/v_tennis_23/v_tennis_23_04.mpg
# Processing 2.057%: /tennis_swing/v_tennis_23/v_tennis_23_01.mpg
# Processing 2.185%: /tennis_swing/v_tennis_23/v_tennis_23_03.mpg
# Processing 2.314%: /tennis_swing/v_tennis_23/v_tennis_23_02.mpg
# Processing 2.442%: /tennis_swing/v_tennis_23/v_tennis_23_06.mpg
# Processing 2.571%: /tennis_swing/v_tennis_08/v_tennis_08_03.mpg
# Processing 2.699%: /tennis_swing/v_tennis_08/v_tennis_08_01.mpg
# Processing 2.828%: /tennis_swing/v_tennis_08/v_tennis_08_05.mpg
# Processing 2.956%: /tennis_swing/v_tennis_08/v_tennis_08_04.mpg
# Processing 3.085%: /tennis_swing/v_tennis_08/v_tennis_08_02.mpg
# Processing 3.213%: /tennis_swing/v_tennis_08/v_tennis_08_06.mpg
# Processing 3.342%: /tennis_swing/v_tennis_02/v_tennis_02_02.mpg
# Processing 3.47%: /tennis_swing/v_tennis_02/v_tennis_02_07.mpg
# Processing 3.599%: /tennis_swing/v_tennis_02/v_tennis_02_04.mpg
# Processing 3.728%: /tennis_swing/v_tennis_02/v_tennis_02_01.mpg
# Processing 3.856%: /tennis_swing/v_tennis_02/v_tennis_02_03.mpg
# Processing 3.985%: /tennis_swing/v_tennis_02/v_tennis_02_06.mpg
# Processing 4.113%: /tennis_swing/v_tennis_02/v_tennis_02_05.mpg
# Processing 4.242%: /tennis_swing/v_tennis_16/v_tennis_16_04.mpg
# Processing 4.37%: /tennis_swing/v_tennis_16/v_tennis_16_02.mpg
# Processing 4.499%: /tennis_swing/v_tennis_16/v_tennis_16_07.mpg
# Processing 4.627%: /tennis_swing/v_tennis_16/v_tennis_16_01.mpg
# Processing 4.756%: /tennis_swing/v_tennis_16/v_tennis_16_06.mpg
# Processing 4.884%: /tennis_swing/v_tennis_16/v_tennis_16_05.mpg
# Processing 5.013%: /tennis_swing/v_tennis_16/v_tennis_16_03.mpg
# Processing 5.141%: /tennis_swing/v_tennis_03/v_tennis_03_06.mpg
# Processing 5.27%: /tennis_swing/v_tennis_03/v_tennis_03_04.mpg
# Processing 5.398%: /tennis_swing/v_tennis_03/v_tennis_03_01.mpg
# Processing 5.527%: /tennis_swing/v_tennis_03/v_tennis_03_07.mpg
# Processing 5.656%: /tennis_swing/v_tennis_03/v_tennis_03_03.mpg
# Processing 5.784%: /tennis_swing/v_tennis_03/v_tennis_03_05.mpg
# Processing 5.913%: /tennis_swing/v_tennis_03/v_tennis_03_02.mpg
# Processing 6.041%: /tennis_swing/v_tennis_06/v_tennis_06_01.mpg
# Processing 6.17%: /tennis_swing/v_tennis_06/v_tennis_06_03.mpg
# Processing 6.298%: /tennis_swing/v_tennis_06/v_tennis_06_07.mpg
# Processing 6.427%: /tennis_swing/v_tennis_06/v_tennis_06_02.mpg
# Processing 6.555%: /tennis_swing/v_tennis_06/v_tennis_06_04.mpg
# Processing 6.684%: /tennis_swing/v_tennis_06/v_tennis_06_05.mpg
# Processing 6.812%: /tennis_swing/v_tennis_06/v_tennis_06_06.mpg
# Processing 6.941%: /tennis_swing/v_tennis_07/v_tennis_07_05.mpg
# Processing 7.069%: /tennis_swing/v_tennis_07/v_tennis_07_06.mpg
# Processing 7.198%: /tennis_swing/v_tennis_07/v_tennis_07_07.mpg
# Processing 7.326%: /tennis_swing/v_tennis_07/v_tennis_07_04.mpg
# Processing 7.455%: /tennis_swing/v_tennis_07/v_tennis_07_01.mpg
# Processing 7.584%: /tennis_swing/v_tennis_07/v_tennis_07_03.mpg
# Processing 7.712%: /tennis_swing/v_tennis_07/v_tennis_07_02.mpg
# Processing 7.841%: /tennis_swing/v_tennis_24/v_tennis_24_04.mpg
# Processing 7.969%: /tennis_swing/v_tennis_24/v_tennis_24_01.mpg
# Processing 8.098%: /tennis_swing/v_tennis_24/v_tennis_24_02.mpg
# Processing 8.226%: /tennis_swing/v_tennis_24/v_tennis_24_05.mpg
# Processing 8.355%: /tennis_swing/v_tennis_24/v_tennis_24_03.mpg
# Processing 8.483%: /tennis_swing/v_tennis_24/v_tennis_24_06.mpg
# Processing 8.612%: /tennis_swing/v_tennis_12/v_tennis_12_06.mpg
# Processing 8.74%: /tennis_swing/v_tennis_12/v_tennis_12_02.mpg
# Processing 8.869%: /tennis_swing/v_tennis_12/v_tennis_12_07.mpg
# Processing 8.997%: /tennis_swing/v_tennis_12/v_tennis_12_04.mpg
# Processing 9.126%: /tennis_swing/v_tennis_12/v_tennis_12_05.mpg
# Processing 9.254%: /tennis_swing/v_tennis_12/v_tennis_12_01.mpg
# Processing 9.383%: /tennis_swing/v_tennis_12/v_tennis_12_03.mpg
# Processing 9.512%: /tennis_swing/v_tennis_19/v_tennis_19_02.mpg
# Processing 9.64%: /tennis_swing/v_tennis_19/v_tennis_19_05.mpg
# Processing 9.769%: /tennis_swing/v_tennis_19/v_tennis_19_06.mpg
# Processing 9.897%: /tennis_swing/v_tennis_19/v_tennis_19_03.mpg
# Processing 10.026%: /tennis_swing/v_tennis_19/v_tennis_19_01.mpg
# Processing 10.154%: /tennis_swing/v_tennis_19/v_tennis_19_04.mpg
# Processing 10.283%: /tennis_swing/v_tennis_04/v_tennis_04_05.mpg
# Processing 10.411%: /tennis_swing/v_tennis_04/v_tennis_04_01.mpg
# Processing 10.54%: /tennis_swing/v_tennis_04/v_tennis_04_04.mpg
# Processing 10.668%: /tennis_swing/v_tennis_04/v_tennis_04_03.mpg
# Processing 10.797%: /tennis_swing/v_tennis_04/v_tennis_04_02.mpg
# Processing 10.925%: /tennis_swing/v_tennis_04/v_tennis_04_07.mpg
# Processing 11.054%: /tennis_swing/v_tennis_04/v_tennis_04_06.mpg
# Processing 11.183%: /tennis_swing/v_tennis_17/v_tennis_17_07.mpg
# Processing 11.311%: /tennis_swing/v_tennis_17/v_tennis_17_04.mpg
# Processing 11.44%: /tennis_swing/v_tennis_17/v_tennis_17_01.mpg
# Processing 11.568%: /tennis_swing/v_tennis_17/v_tennis_17_06.mpg
# Processing 11.697%: /tennis_swing/v_tennis_17/v_tennis_17_02.mpg
# Processing 11.825%: /tennis_swing/v_tennis_17/v_tennis_17_05.mpg
# Processing 11.954%: /tennis_swing/v_tennis_17/v_tennis_17_03.mpg
# Processing 12.082%: /tennis_swing/v_tennis_15/v_tennis_15_05.mpg
# Processing 12.211%: /tennis_swing/v_tennis_15/v_tennis_15_06.mpg
# Processing 12.339%: /tennis_swing/v_tennis_15/v_tennis_15_08.mpg
# Processing 12.468%: /tennis_swing/v_tennis_15/v_tennis_15_03.mpg
# Processing 12.596%: /tennis_swing/v_tennis_15/v_tennis_15_02.mpg
# Processing 12.725%: /tennis_swing/v_tennis_15/v_tennis_15_07.mpg
# Processing 12.853%: /tennis_swing/v_tennis_15/v_tennis_15_04.mpg
# Processing 12.982%: /tennis_swing/v_tennis_15/v_tennis_15_01.mpg
# Processing 13.111%: /tennis_swing/v_tennis_10/v_tennis_10_01.mpg
# Processing 13.239%: /tennis_swing/v_tennis_10/v_tennis_10_02.mpg
# Processing 13.368%: /tennis_swing/v_tennis_10/v_tennis_10_04.mpg
# Processing 13.496%: /tennis_swing/v_tennis_10/v_tennis_10_06.mpg
# Processing 13.625%: /tennis_swing/v_tennis_10/v_tennis_10_03.mpg
# Processing 13.753%: /tennis_swing/v_tennis_10/v_tennis_10_07.mpg
# Processing 13.882%: /tennis_swing/v_tennis_10/v_tennis_10_05.mpg
# Processing 14.01%: /tennis_swing/v_tennis_20/v_tennis_20_06.mpg
# Processing 14.139%: /tennis_swing/v_tennis_20/v_tennis_20_05.mpg
# Processing 14.267%: /tennis_swing/v_tennis_20/v_tennis_20_03.mpg
# Processing 14.396%: /tennis_swing/v_tennis_20/v_tennis_20_04.mpg
# Processing 14.524%: /tennis_swing/v_tennis_20/v_tennis_20_01.mpg
# Processing 14.653%: /tennis_swing/v_tennis_20/v_tennis_20_02.mpg
# Processing 14.781%: /tennis_swing/v_tennis_22/v_tennis_22_02.mpg
# Processing 14.91%: /tennis_swing/v_tennis_22/v_tennis_22_03.mpg
# Processing 15.039%: /tennis_swing/v_tennis_22/v_tennis_22_05.mpg
# Processing 15.167%: /tennis_swing/v_tennis_22/v_tennis_22_06.mpg
# Processing 15.296%: /tennis_swing/v_tennis_22/v_tennis_22_04.mpg
# Processing 15.424%: /tennis_swing/v_tennis_22/v_tennis_22_01.mpg
# Processing 15.553%: /tennis_swing/v_tennis_11/v_tennis_11_03.mpg
# Processing 15.681%: /tennis_swing/v_tennis_11/v_tennis_11_04.mpg
# Processing 15.81%: /tennis_swing/v_tennis_11/v_tennis_11_02.mpg
# Processing 15.938%: /tennis_swing/v_tennis_11/v_tennis_11_05.mpg
# Processing 16.067%: /tennis_swing/v_tennis_11/v_tennis_11_06.mpg
# Processing 16.195%: /tennis_swing/v_tennis_11/v_tennis_11_01.mpg
# Processing 16.324%: /tennis_swing/v_tennis_11/v_tennis_11_07.mpg
# Processing 16.452%: /tennis_swing/v_tennis_13/v_tennis_13_03.mpg
# Processing 16.581%: /tennis_swing/v_tennis_13/v_tennis_13_05.mpg
# Processing 16.71%: /tennis_swing/v_tennis_13/v_tennis_13_06.mpg
# Processing 16.838%: /tennis_swing/v_tennis_13/v_tennis_13_01.mpg
# Processing 16.967%: /tennis_swing/v_tennis_13/v_tennis_13_02.mpg
# Processing 17.095%: /tennis_swing/v_tennis_13/v_tennis_13_07.mpg
# Processing 17.224%: /tennis_swing/v_tennis_13/v_tennis_13_04.mpg
# Processing 17.352%: /tennis_swing/v_tennis_18/v_tennis_18_02.mpg
# Processing 17.481%: /tennis_swing/v_tennis_18/v_tennis_18_04.mpg
# Processing 17.609%: /tennis_swing/v_tennis_18/v_tennis_18_06.mpg
# Processing 17.738%: /tennis_swing/v_tennis_18/v_tennis_18_05.mpg
# Processing 17.866%: /tennis_swing/v_tennis_18/v_tennis_18_03.mpg
# Processing 17.995%: /tennis_swing/v_tennis_18/v_tennis_18_01.mpg
# Processing 18.123%: /tennis_swing/v_tennis_25/v_tennis_25_03.mpg
# Processing 18.252%: /tennis_swing/v_tennis_25/v_tennis_25_06.mpg
# Processing 18.38%: /tennis_swing/v_tennis_25/v_tennis_25_05.mpg
# Processing 18.509%: /tennis_swing/v_tennis_25/v_tennis_25_01.mpg
# Processing 18.638%: /tennis_swing/v_tennis_25/v_tennis_25_02.mpg
# Processing 18.766%: /tennis_swing/v_tennis_25/v_tennis_25_04.mpg
# Processing 18.895%: /tennis_swing/v_tennis_01/v_tennis_01_04.mpg
# Processing 19.023%: /tennis_swing/v_tennis_01/v_tennis_01_02.mpg
# Processing 19.152%: /tennis_swing/v_tennis_01/v_tennis_01_06.mpg
# Processing 19.28%: /tennis_swing/v_tennis_01/v_tennis_01_01.mpg
# Processing 19.409%: /tennis_swing/v_tennis_01/v_tennis_01_05.mpg
# Processing 19.537%: /tennis_swing/v_tennis_01/v_tennis_01_03.mpg
# Processing 19.666%: /tennis_swing/v_tennis_01/v_tennis_01_07.mpg
# Processing 19.794%: /tennis_swing/v_tennis_09/v_tennis_09_02.mpg
# Processing 19.923%: /tennis_swing/v_tennis_09/v_tennis_09_04.mpg
# Processing 20.051%: /tennis_swing/v_tennis_09/v_tennis_09_03.mpg
# Processing 20.18%: /tennis_swing/v_tennis_09/v_tennis_09_01.mpg
# Processing 20.308%: /tennis_swing/v_tennis_09/v_tennis_09_06.mpg
# Processing 20.437%: /tennis_swing/v_tennis_09/v_tennis_09_05.mpg
# Processing 20.566%: /tennis_swing/v_tennis_09/v_tennis_09_07.mpg
# Processing 20.694%: /tennis_swing/v_tennis_21/v_tennis_21_05.mpg
# Processing 20.823%: /tennis_swing/v_tennis_21/v_tennis_21_04.mpg
# Processing 20.951%: /tennis_swing/v_tennis_21/v_tennis_21_06.mpg
# Processing 21.08%: /tennis_swing/v_tennis_21/v_tennis_21_01.mpg
# Processing 21.208%: /tennis_swing/v_tennis_21/v_tennis_21_02.mpg
# Processing 21.337%: /tennis_swing/v_tennis_21/v_tennis_21_03.mpg
# Processing 21.465%: /volleyball_spiking/v_spiking_09/v_spiking_09_02.mpg
# Processing 21.594%: /volleyball_spiking/v_spiking_09/v_spiking_09_05.mpg
# Processing 21.722%: /volleyball_spiking/v_spiking_09/v_spiking_09_04.mpg
# Processing 21.851%: /volleyball_spiking/v_spiking_09/v_spiking_09_06.mpg
# Processing 21.979%: /volleyball_spiking/v_spiking_09/v_spiking_09_03.mpg
# Processing 22.108%: /volleyball_spiking/v_spiking_09/v_spiking_09_01.mpg
# Processing 22.237%: /volleyball_spiking/v_spiking_15/v_spiking_15_04.mpg
# Processing 22.365%: /volleyball_spiking/v_spiking_15/v_spiking_15_03.mpg
# Processing 22.494%: /volleyball_spiking/v_spiking_15/v_spiking_15_02.mpg
# Processing 22.622%: /volleyball_spiking/v_spiking_15/v_spiking_15_01.mpg
# Processing 22.751%: /volleyball_spiking/v_spiking_19/v_spiking_19_01.mpg
# Processing 22.879%: /volleyball_spiking/v_spiking_19/v_spiking_19_03.mpg
# Processing 23.008%: /volleyball_spiking/v_spiking_19/v_spiking_19_04.mpg
# Processing 23.136%: /volleyball_spiking/v_spiking_19/v_spiking_19_02.mpg
# Processing 23.265%: /volleyball_spiking/v_spiking_01/v_spiking_01_01.mpg
# Processing 23.393%: /volleyball_spiking/v_spiking_01/v_spiking_01_02.mpg
# Processing 23.522%: /volleyball_spiking/v_spiking_01/v_spiking_01_03.mpg
# Processing 23.65%: /volleyball_spiking/v_spiking_01/v_spiking_01_04.mpg
# Processing 23.779%: /volleyball_spiking/v_spiking_13/v_spiking_13_05.mpg
# Processing 23.907%: /volleyball_spiking/v_spiking_13/v_spiking_13_06.mpg
# Processing 24.036%: /volleyball_spiking/v_spiking_13/v_spiking_13_04.mpg
# Processing 24.165%: /volleyball_spiking/v_spiking_13/v_spiking_13_07.mpg
# Processing 24.293%: /volleyball_spiking/v_spiking_13/v_spiking_13_03.mpg
# Processing 24.422%: /volleyball_spiking/v_spiking_13/v_spiking_13_02.mpg
# Processing 24.55%: /volleyball_spiking/v_spiking_13/v_spiking_13_01.mpg
# Processing 24.679%: /volleyball_spiking/v_spiking_07/v_spiking_07_03.mpg
# Processing 24.807%: /volleyball_spiking/v_spiking_07/v_spiking_07_07.mpg
# Processing 24.936%: /volleyball_spiking/v_spiking_07/v_spiking_07_02.mpg
# Processing 25.064%: /volleyball_spiking/v_spiking_07/v_spiking_07_05.mpg
# Processing 25.193%: /volleyball_spiking/v_spiking_07/v_spiking_07_04.mpg
# Processing 25.321%: /volleyball_spiking/v_spiking_07/v_spiking_07_06.mpg
# Processing 25.45%: /volleyball_spiking/v_spiking_07/v_spiking_07_01.mpg
# Processing 25.578%: /volleyball_spiking/v_spiking_17/v_spiking_17_02.mpg
# Processing 25.707%: /volleyball_spiking/v_spiking_17/v_spiking_17_04.mpg
# Processing 25.835%: /volleyball_spiking/v_spiking_17/v_spiking_17_01.mpg
# Processing 25.964%: /volleyball_spiking/v_spiking_17/v_spiking_17_03.mpg
# Processing 26.093%: /volleyball_spiking/v_spiking_22/v_spiking_22_04.mpg
# Processing 26.221%: /volleyball_spiking/v_spiking_22/v_spiking_22_03.mpg
# Processing 26.35%: /volleyball_spiking/v_spiking_22/v_spiking_22_01.mpg
# Processing 26.478%: /volleyball_spiking/v_spiking_22/v_spiking_22_02.mpg
# Processing 26.607%: /volleyball_spiking/v_spiking_12/v_spiking_12_03.mpg
# Processing 26.735%: /volleyball_spiking/v_spiking_12/v_spiking_12_01.mpg
# Processing 26.864%: /volleyball_spiking/v_spiking_12/v_spiking_12_04.mpg
# Processing 26.992%: /volleyball_spiking/v_spiking_12/v_spiking_12_02.mpg
# Processing 27.121%: /volleyball_spiking/v_spiking_11/v_spiking_11_03.mpg
# Processing 27.249%: /volleyball_spiking/v_spiking_11/v_spiking_11_02.mpg
# Processing 27.378%: /volleyball_spiking/v_spiking_11/v_spiking_11_05.mpg
# Processing 27.506%: /volleyball_spiking/v_spiking_11/v_spiking_11_06.mpg
# Processing 27.635%: /volleyball_spiking/v_spiking_11/v_spiking_11_01.mpg
# Processing 27.763%: /volleyball_spiking/v_spiking_11/v_spiking_11_04.mpg
# Processing 27.892%: /volleyball_spiking/v_spiking_03/v_spiking_03_01.mpg
# Processing 28.021%: /volleyball_spiking/v_spiking_03/v_spiking_03_03.mpg
# Processing 28.149%: /volleyball_spiking/v_spiking_03/v_spiking_03_04.mpg
# Processing 28.278%: /volleyball_spiking/v_spiking_03/v_spiking_03_02.mpg
# Processing 28.406%: /volleyball_spiking/v_spiking_04/v_spiking_04_05.mpg
# Processing 28.535%: /volleyball_spiking/v_spiking_04/v_spiking_04_01.mpg
# Processing 28.663%: /volleyball_spiking/v_spiking_04/v_spiking_04_07.mpg
# Processing 28.792%: /volleyball_spiking/v_spiking_04/v_spiking_04_04.mpg
# Processing 28.92%: /volleyball_spiking/v_spiking_04/v_spiking_04_06.mpg
# Processing 29.049%: /volleyball_spiking/v_spiking_04/v_spiking_04_03.mpg
# Processing 29.177%: /volleyball_spiking/v_spiking_04/v_spiking_04_02.mpg
# Processing 29.306%: /volleyball_spiking/v_spiking_05/v_spiking_05_02.mpg
# Processing 29.434%: /volleyball_spiking/v_spiking_05/v_spiking_05_04.mpg
# Processing 29.563%: /volleyball_spiking/v_spiking_05/v_spiking_05_03.mpg
# Processing 29.692%: /volleyball_spiking/v_spiking_05/v_spiking_05_01.mpg
# Processing 29.82%: /volleyball_spiking/v_spiking_05/v_spiking_05_05.mpg
# Processing 29.949%: /volleyball_spiking/v_spiking_23/v_spiking_23_03.mpg
# Processing 30.077%: /volleyball_spiking/v_spiking_23/v_spiking_23_01.mpg
# Processing 30.206%: /volleyball_spiking/v_spiking_23/v_spiking_23_04.mpg
# Processing 30.334%: /volleyball_spiking/v_spiking_23/v_spiking_23_02.mpg
# Processing 30.463%: /volleyball_spiking/v_spiking_08/v_spiking_08_01.mpg
# Processing 30.591%: /volleyball_spiking/v_spiking_08/v_spiking_08_05.mpg
# Processing 30.72%: /volleyball_spiking/v_spiking_08/v_spiking_08_04.mpg
# Processing 30.848%: /volleyball_spiking/v_spiking_08/v_spiking_08_06.mpg
# Processing 30.977%: /volleyball_spiking/v_spiking_08/v_spiking_08_03.mpg
# Processing 31.105%: /volleyball_spiking/v_spiking_08/v_spiking_08_02.mpg
# Processing 31.234%: /volleyball_spiking/v_spiking_14/v_spiking_14_04.mpg
# Processing 31.362%: /volleyball_spiking/v_spiking_14/v_spiking_14_03.mpg
# Processing 31.491%: /volleyball_spiking/v_spiking_14/v_spiking_14_01.mpg
# Processing 31.62%: /volleyball_spiking/v_spiking_14/v_spiking_14_02.mpg
# Processing 31.748%: /volleyball_spiking/v_spiking_25/v_spiking_25_03.mpg
# Processing 31.877%: /volleyball_spiking/v_spiking_25/v_spiking_25_04.mpg
# Processing 32.005%: /volleyball_spiking/v_spiking_25/v_spiking_25_02.mpg
# Processing 32.134%: /volleyball_spiking/v_spiking_25/v_spiking_25_01.mpg
# Processing 32.262%: /volleyball_spiking/v_spiking_21/v_spiking_21_02.mpg
# Processing 32.391%: /volleyball_spiking/v_spiking_21/v_spiking_21_04.mpg
# Processing 32.519%: /volleyball_spiking/v_spiking_21/v_spiking_21_03.mpg
# Processing 32.648%: /volleyball_spiking/v_spiking_21/v_spiking_21_01.mpg
# Processing 32.776%: /volleyball_spiking/v_spiking_24/v_spiking_24_03.mpg
# Processing 32.905%: /volleyball_spiking/v_spiking_24/v_spiking_24_04.mpg
# Processing 33.033%: /volleyball_spiking/v_spiking_24/v_spiking_24_01.mpg
# Processing 33.162%: /volleyball_spiking/v_spiking_24/v_spiking_24_02.mpg
# Processing 33.29%: /volleyball_spiking/v_spiking_18/v_spiking_18_01.mpg
# Processing 33.419%: /volleyball_spiking/v_spiking_18/v_spiking_18_03.mpg
# Processing 33.548%: /volleyball_spiking/v_spiking_18/v_spiking_18_02.mpg
# Processing 33.676%: /volleyball_spiking/v_spiking_18/v_spiking_18_04.mpg
# Processing 33.805%: /volleyball_spiking/v_spiking_06/v_spiking_06_01.mpg
# Processing 33.933%: /volleyball_spiking/v_spiking_06/v_spiking_06_04.mpg
# Processing 34.062%: /volleyball_spiking/v_spiking_06/v_spiking_06_02.mpg
# Processing 34.19%: /volleyball_spiking/v_spiking_06/v_spiking_06_03.mpg
# Processing 34.319%: /volleyball_spiking/v_spiking_10/v_spiking_10_02.mpg
# Processing 34.447%: /volleyball_spiking/v_spiking_10/v_spiking_10_04.mpg
# Processing 34.576%: /volleyball_spiking/v_spiking_10/v_spiking_10_03.mpg
# Processing 34.704%: /volleyball_spiking/v_spiking_10/v_spiking_10_01.mpg
# Processing 34.833%: /volleyball_spiking/v_spiking_20/v_spiking_20_03.mpg
# Processing 34.961%: /volleyball_spiking/v_spiking_20/v_spiking_20_01.mpg
# Processing 35.09%: /volleyball_spiking/v_spiking_20/v_spiking_20_04.mpg
# Processing 35.219%: /volleyball_spiking/v_spiking_20/v_spiking_20_02.mpg
# Processing 35.347%: /volleyball_spiking/v_spiking_16/v_spiking_16_03.mpg
# Processing 35.476%: /volleyball_spiking/v_spiking_16/v_spiking_16_02.mpg
# Processing 35.604%: /volleyball_spiking/v_spiking_16/v_spiking_16_04.mpg
# Processing 35.733%: /volleyball_spiking/v_spiking_16/v_spiking_16_01.mpg
# Processing 35.861%: /volleyball_spiking/v_spiking_02/v_spiking_02_01.mpg
# Processing 35.99%: /volleyball_spiking/v_spiking_02/v_spiking_02_03.mpg
# Processing 36.118%: /volleyball_spiking/v_spiking_02/v_spiking_02_04.mpg
# Processing 36.247%: /volleyball_spiking/v_spiking_02/v_spiking_02_02.mpg
# Processing 36.375%: /basketball/v_shooting_05/v_shooting_05_01.mpg
# Processing 36.504%: /basketball/v_shooting_05/v_shooting_05_04.mpg
# Processing 36.632%: /basketball/v_shooting_05/v_shooting_05_03.mpg
# Processing 36.761%: /basketball/v_shooting_05/v_shooting_05_02.mpg
# Processing 36.889%: /basketball/v_shooting_09/v_shooting_09_05.mpg
# Processing 37.018%: /basketball/v_shooting_09/v_shooting_09_03.mpg
# Processing 37.147%: /basketball/v_shooting_09/v_shooting_09_01.mpg
# Processing 37.275%: /basketball/v_shooting_09/v_shooting_09_04.mpg
# Processing 37.404%: /basketball/v_shooting_09/v_shooting_09_02.mpg
# Processing 37.532%: /basketball/v_shooting_19/v_shooting_19_08.mpg
# Processing 37.661%: /basketball/v_shooting_19/v_shooting_19_06.mpg
# Processing 37.789%: /basketball/v_shooting_19/v_shooting_19_05.mpg
# Processing 37.918%: /basketball/v_shooting_19/v_shooting_19_07.mpg
# Processing 38.046%: /basketball/v_shooting_19/v_shooting_19_04.mpg
# Processing 38.175%: /basketball/v_shooting_19/v_shooting_19_01.mpg
# Processing 38.303%: /basketball/v_shooting_19/v_shooting_19_03.mpg
# Processing 38.432%: /basketball/v_shooting_19/v_shooting_19_02.mpg
# Processing 38.56%: /basketball/v_shooting_17/v_shooting_17_02.mpg
# Processing 38.689%: /basketball/v_shooting_17/v_shooting_17_01.mpg
# Processing 38.817%: /basketball/v_shooting_17/v_shooting_17_03.mpg
# Processing 38.946%: /basketball/v_shooting_17/v_shooting_17_04.mpg
# Processing 39.075%: /basketball/v_shooting_21/v_shooting_21_01.mpg
# Processing 39.203%: /basketball/v_shooting_21/v_shooting_21_05.mpg
# Processing 39.332%: /basketball/v_shooting_21/v_shooting_21_02.mpg
# Processing 39.46%: /basketball/v_shooting_21/v_shooting_21_04.mpg
# Processing 39.589%: /basketball/v_shooting_21/v_shooting_21_03.mpg
# Processing 39.717%: /basketball/v_shooting_21/v_shooting_21_06.mpg
# Processing 39.846%: /basketball/v_shooting_10/v_shooting_10_02.mpg
# Processing 39.974%: /basketball/v_shooting_10/v_shooting_10_05.mpg
# Processing 40.103%: /basketball/v_shooting_10/v_shooting_10_03.mpg
# Processing 40.231%: /basketball/v_shooting_10/v_shooting_10_04.mpg
# Processing 40.36%: /basketball/v_shooting_10/v_shooting_10_01.mpg
# Processing 40.488%: /basketball/v_shooting_13/v_shooting_13_03.mpg
# Processing 40.617%: /basketball/v_shooting_13/v_shooting_13_01.mpg
# Processing 40.746%: /basketball/v_shooting_13/v_shooting_13_02.mpg
# Processing 40.874%: /basketball/v_shooting_13/v_shooting_13_04.mpg
# Processing 41.003%: /basketball/v_shooting_23/v_shooting_23_05.mpg
# Processing 41.131%: /basketball/v_shooting_23/v_shooting_23_02.mpg
# Processing 41.26%: /basketball/v_shooting_23/v_shooting_23_04.mpg
# Processing 41.388%: /basketball/v_shooting_23/v_shooting_23_03.mpg
# Processing 41.517%: /basketball/v_shooting_23/v_shooting_23_06.mpg
# Processing 41.645%: /basketball/v_shooting_23/v_shooting_23_01.mpg
# Processing 41.774%: /basketball/v_shooting_04/v_shooting_04_01.mpg
# Processing 41.902%: /basketball/v_shooting_04/v_shooting_04_04.mpg
# Processing 42.031%: /basketball/v_shooting_04/v_shooting_04_02.mpg
# Processing 42.159%: /basketball/v_shooting_04/v_shooting_04_03.mpg
# Processing 42.288%: /basketball/v_shooting_14/v_shooting_14_05.mpg
# Processing 42.416%: /basketball/v_shooting_14/v_shooting_14_03.mpg
# Processing 42.545%: /basketball/v_shooting_14/v_shooting_14_04.mpg
# Processing 42.674%: /basketball/v_shooting_14/v_shooting_14_02.mpg
# Processing 42.802%: /basketball/v_shooting_14/v_shooting_14_01.mpg
# Processing 42.931%: /basketball/v_shooting_03/v_shooting_03_03.mpg
# Processing 43.059%: /basketball/v_shooting_03/v_shooting_03_02.mpg
# Processing 43.188%: /basketball/v_shooting_03/v_shooting_03_04.mpg
# Processing 43.316%: /basketball/v_shooting_03/v_shooting_03_01.mpg
# Processing 43.445%: /basketball/v_shooting_03/v_shooting_03_06.mpg
# Processing 43.573%: /basketball/v_shooting_03/v_shooting_03_05.mpg
# Processing 43.702%: /basketball/v_shooting_06/v_shooting_06_02.mpg
# Processing 43.83%: /basketball/v_shooting_06/v_shooting_06_03.mpg
# Processing 43.959%: /basketball/v_shooting_06/v_shooting_06_01.mpg
# Processing 44.087%: /basketball/v_shooting_06/v_shooting_06_04.mpg
# Processing 44.216%: /basketball/v_shooting_11/v_shooting_11_04.mpg
# Processing 44.344%: /basketball/v_shooting_11/v_shooting_11_02.mpg
# Processing 44.473%: /basketball/v_shooting_11/v_shooting_11_03.mpg
# Processing 44.602%: /basketball/v_shooting_11/v_shooting_11_01.mpg
# Processing 44.73%: /basketball/v_shooting_11/v_shooting_11_05.mpg
# Processing 44.859%: /basketball/v_shooting_18/v_shooting_18_05.mpg
# Processing 44.987%: /basketball/v_shooting_18/v_shooting_18_02.mpg
# Processing 45.116%: /basketball/v_shooting_18/v_shooting_18_01.mpg
# Processing 45.244%: /basketball/v_shooting_18/v_shooting_18_03.mpg
# Processing 45.373%: /basketball/v_shooting_18/v_shooting_18_04.mpg
# Processing 45.501%: /basketball/v_shooting_01/v_shooting_01_07.mpg
# Processing 45.63%: /basketball/v_shooting_01/v_shooting_01_06.mpg
# Processing 45.758%: /basketball/v_shooting_01/v_shooting_01_04.mpg
# Processing 45.887%: /basketball/v_shooting_01/v_shooting_01_05.mpg
# Processing 46.015%: /basketball/v_shooting_01/v_shooting_01_02.mpg
# Processing 46.144%: /basketball/v_shooting_01/v_shooting_01_03.mpg
# Processing 46.272%: /basketball/v_shooting_01/v_shooting_01_01.mpg
# Processing 46.401%: /basketball/v_shooting_15/v_shooting_15_05.mpg
# Processing 46.53%: /basketball/v_shooting_15/v_shooting_15_02.mpg
# Processing 46.658%: /basketball/v_shooting_15/v_shooting_15_04.mpg
# Processing 46.787%: /basketball/v_shooting_15/v_shooting_15_07.mpg
# Processing 46.915%: /basketball/v_shooting_15/v_shooting_15_01.mpg
# Processing 47.044%: /basketball/v_shooting_15/v_shooting_15_06.mpg
# Processing 47.172%: /basketball/v_shooting_15/v_shooting_15_03.mpg
# Processing 47.301%: /basketball/v_shooting_16/v_shooting_16_03.mpg
# Processing 47.429%: /basketball/v_shooting_16/v_shooting_16_07.mpg
# Processing 47.558%: /basketball/v_shooting_16/v_shooting_16_06.mpg
# Processing 47.686%: /basketball/v_shooting_16/v_shooting_16_04.mpg
# Processing 47.815%: /basketball/v_shooting_16/v_shooting_16_05.mpg
# Video /basketball/v_shooting_16/v_shooting_16_05.mpg có ít hơn 16 frames. Sẽ lấy tất cả 10 frames.
# Video /basketball/v_shooting_16/v_shooting_16_05.mpg không đủ số frame sau khi xử lý, sẽ bỏ qua.
# Processing 47.943%: /basketball/v_shooting_16/v_shooting_16_01.mpg
# Processing 48.072%: /basketball/v_shooting_16/v_shooting_16_02.mpg
# Processing 48.201%: /basketball/v_shooting_07/v_shooting_07_04.mpg
# Processing 48.329%: /basketball/v_shooting_07/v_shooting_07_01.mpg
# Processing 48.458%: /basketball/v_shooting_07/v_shooting_07_03.mpg
# Processing 48.586%: /basketball/v_shooting_07/v_shooting_07_02.mpg
# Processing 48.715%: /basketball/v_shooting_02/v_shooting_02_05.mpg
# Processing 48.843%: /basketball/v_shooting_02/v_shooting_02_04.mpg
# Processing 48.972%: /basketball/v_shooting_02/v_shooting_02_03.mpg
# Processing 49.1%: /basketball/v_shooting_02/v_shooting_02_06.mpg
# Processing 49.229%: /basketball/v_shooting_02/v_shooting_02_02.mpg
# Processing 49.357%: /basketball/v_shooting_02/v_shooting_02_01.mpg
# Processing 49.486%: /basketball/v_shooting_25/v_shooting_25_04.mpg
# Processing 49.614%: /basketball/v_shooting_25/v_shooting_25_02.mpg
# Processing 49.743%: /basketball/v_shooting_25/v_shooting_25_01.mpg
# Processing 49.871%: /basketball/v_shooting_25/v_shooting_25_03.mpg
# Processing 50.0%: /basketball/v_shooting_25/v_shooting_25_07.mpg
# Processing 50.129%: /basketball/v_shooting_25/v_shooting_25_05.mpg
# Processing 50.257%: /basketball/v_shooting_25/v_shooting_25_08.mpg
# Processing 50.386%: /basketball/v_shooting_25/v_shooting_25_06.mpg
# Video /basketball/v_shooting_25/v_shooting_25_06.mpg có ít hơn 16 frames. Sẽ lấy tất cả 12 frames.
# Video /basketball/v_shooting_25/v_shooting_25_06.mpg không đủ số frame sau khi xử lý, sẽ bỏ qua.
# Processing 50.514%: /basketball/v_shooting_25/v_shooting_25_09.mpg
# Processing 50.643%: /basketball/v_shooting_12/v_shooting_12_03.mpg
# Processing 50.771%: /basketball/v_shooting_12/v_shooting_12_02.mpg
# Processing 50.9%: /basketball/v_shooting_12/v_shooting_12_05.mpg
# Processing 51.028%: /basketball/v_shooting_12/v_shooting_12_01.mpg
# Processing 51.157%: /basketball/v_shooting_12/v_shooting_12_04.mpg
# Processing 51.285%: /basketball/v_shooting_20/v_shooting_20_05.mpg
# Processing 51.414%: /basketball/v_shooting_20/v_shooting_20_03.mpg
# Processing 51.542%: /basketball/v_shooting_20/v_shooting_20_06.mpg
# Processing 51.671%: /basketball/v_shooting_20/v_shooting_20_07.mpg
# Processing 51.799%: /basketball/v_shooting_20/v_shooting_20_04.mpg
# Processing 51.928%: /basketball/v_shooting_20/v_shooting_20_02.mpg
# Processing 52.057%: /basketball/v_shooting_20/v_shooting_20_01.mpg
# Processing 52.185%: /basketball/v_shooting_08/v_shooting_08_04.mpg
# Processing 52.314%: /basketball/v_shooting_08/v_shooting_08_01.mpg
# Processing 52.442%: /basketball/v_shooting_08/v_shooting_08_03.mpg
# Processing 52.571%: /basketball/v_shooting_08/v_shooting_08_02.mpg
# Processing 52.699%: /basketball/v_shooting_22/v_shooting_22_06.mpg
# Processing 52.828%: /basketball/v_shooting_22/v_shooting_22_07.mpg
# Processing 52.956%: /basketball/v_shooting_22/v_shooting_22_05.mpg
# Processing 53.085%: /basketball/v_shooting_22/v_shooting_22_08.mpg
# Processing 53.213%: /basketball/v_shooting_22/v_shooting_22_01.mpg
# Processing 53.342%: /basketball/v_shooting_22/v_shooting_22_02.mpg
# Processing 53.47%: /basketball/v_shooting_22/v_shooting_22_04.mpg
# Processing 53.599%: /basketball/v_shooting_22/v_shooting_22_03.mpg
# Processing 53.728%: /basketball/v_shooting_24/v_shooting_24_03.mpg
# Processing 53.856%: /basketball/v_shooting_24/v_shooting_24_04.mpg
# Processing 53.985%: /basketball/v_shooting_24/v_shooting_24_01.mpg
# Video /basketball/v_shooting_24/v_shooting_24_01.mpg có ít hơn 16 frames. Sẽ lấy tất cả 1 frames.
# Video /basketball/v_shooting_24/v_shooting_24_01.mpg không đủ số frame sau khi xử lý, sẽ bỏ qua.
# Processing 54.113%: /basketball/v_shooting_24/v_shooting_24_02.mpg
# Processing 54.242%: /basketball/v_shooting_24/v_shooting_24_05.mpg
# Processing 54.37%: /basketball/v_shooting_24/v_shooting_24_06.mpg
# Processing 54.499%: /horse_riding/v_riding_23/v_riding_23_04.mpg
# Processing 54.627%: /horse_riding/v_riding_23/v_riding_23_03.mpg
# Processing 54.756%: /horse_riding/v_riding_23/v_riding_23_05.mpg
# Processing 54.884%: /horse_riding/v_riding_23/v_riding_23_06.mpg
# Processing 55.013%: /horse_riding/v_riding_23/v_riding_23_01.mpg
# Processing 55.141%: /horse_riding/v_riding_23/v_riding_23_02.mpg
# Processing 55.27%: /horse_riding/v_riding_22/v_riding_22_05.mpg
# Processing 55.398%: /horse_riding/v_riding_22/v_riding_22_07.mpg
# Processing 55.527%: /horse_riding/v_riding_22/v_riding_22_01.mpg
# Processing 55.656%: /horse_riding/v_riding_22/v_riding_22_04.mpg
# Processing 55.784%: /horse_riding/v_riding_22/v_riding_22_02.mpg
# Processing 55.913%: /horse_riding/v_riding_22/v_riding_22_06.mpg
# Processing 56.041%: /horse_riding/v_riding_22/v_riding_22_03.mpg
# Processing 56.17%: /horse_riding/v_riding_13/v_riding_13_03.mpg
# Processing 56.298%: /horse_riding/v_riding_13/v_riding_13_01.mpg
# Processing 56.427%: /horse_riding/v_riding_13/v_riding_13_04.mpg
# Processing 56.555%: /horse_riding/v_riding_13/v_riding_13_02.mpg
# Processing 56.684%: /horse_riding/v_riding_05/v_riding_05_08.mpg
# Processing 56.812%: /horse_riding/v_riding_05/v_riding_05_01.mpg
# Processing 56.941%: /horse_riding/v_riding_05/v_riding_05_06.mpg
# Processing 57.069%: /horse_riding/v_riding_05/v_riding_05_05.mpg
# Processing 57.198%: /horse_riding/v_riding_05/v_riding_05_07.mpg
# Processing 57.326%: /horse_riding/v_riding_05/v_riding_05_02.mpg
# Processing 57.455%: /horse_riding/v_riding_05/v_riding_05_03.mpg
# Processing 57.584%: /horse_riding/v_riding_05/v_riding_05_04.mpg
# Processing 57.712%: /horse_riding/v_riding_12/v_riding_12_07.mpg
# Processing 57.841%: /horse_riding/v_riding_12/v_riding_12_03.mpg
# Processing 57.969%: /horse_riding/v_riding_12/v_riding_12_02.mpg
# Processing 58.098%: /horse_riding/v_riding_12/v_riding_12_01.mpg
# Processing 58.226%: /horse_riding/v_riding_12/v_riding_12_06.mpg
# Processing 58.355%: /horse_riding/v_riding_12/v_riding_12_04.mpg
# Processing 58.483%: /horse_riding/v_riding_12/v_riding_12_05.mpg
# Processing 58.612%: /horse_riding/v_riding_21/v_riding_21_03.mpg
# Processing 58.74%: /horse_riding/v_riding_21/v_riding_21_05.mpg
# Processing 58.869%: /horse_riding/v_riding_21/v_riding_21_06.mpg
# Processing 58.997%: /horse_riding/v_riding_21/v_riding_21_01.mpg
# Processing 59.126%: /horse_riding/v_riding_21/v_riding_21_04.mpg
# Processing 59.254%: /horse_riding/v_riding_21/v_riding_21_02.mpg
# Processing 59.383%: /horse_riding/v_riding_11/v_riding_11_03.mpg
# Processing 59.512%: /horse_riding/v_riding_11/v_riding_11_02.mpg
# Processing 59.64%: /horse_riding/v_riding_11/v_riding_11_01.mpg
# Processing 59.769%: /horse_riding/v_riding_11/v_riding_11_07.mpg
# Processing 59.897%: /horse_riding/v_riding_11/v_riding_11_05.mpg
# Processing 60.026%: /horse_riding/v_riding_11/v_riding_11_04.mpg
# Processing 60.154%: /horse_riding/v_riding_11/v_riding_11_06.mpg
# Processing 60.283%: /horse_riding/v_riding_08/v_riding_08_04.mpg
# Processing 60.411%: /horse_riding/v_riding_08/v_riding_08_01.mpg
# Processing 60.54%: /horse_riding/v_riding_08/v_riding_08_05.mpg
# Processing 60.668%: /horse_riding/v_riding_08/v_riding_08_02.mpg
# Processing 60.797%: /horse_riding/v_riding_08/v_riding_08_06.mpg
# Processing 60.925%: /horse_riding/v_riding_08/v_riding_08_03.mpg
# Processing 61.054%: /horse_riding/v_riding_02/v_riding_02_05.mpg
# Processing 61.183%: /horse_riding/v_riding_02/v_riding_02_01.mpg
# Processing 61.311%: /horse_riding/v_riding_02/v_riding_02_03.mpg
# Processing 61.44%: /horse_riding/v_riding_02/v_riding_02_02.mpg
# Processing 61.568%: /horse_riding/v_riding_02/v_riding_02_07.mpg
# Processing 61.697%: /horse_riding/v_riding_02/v_riding_02_08.mpg
# Processing 61.825%: /horse_riding/v_riding_02/v_riding_02_04.mpg
# Processing 61.954%: /horse_riding/v_riding_02/v_riding_02_06.mpg
# Processing 62.082%: /horse_riding/v_riding_02/v_riding_02_09.mpg
# Processing 62.211%: /horse_riding/v_riding_18/v_riding_18_01.mpg
# Processing 62.339%: /horse_riding/v_riding_18/v_riding_18_02.mpg
# Processing 62.468%: /horse_riding/v_riding_18/v_riding_18_06.mpg
# Processing 62.596%: /horse_riding/v_riding_18/v_riding_18_03.mpg
# Processing 62.725%: /horse_riding/v_riding_18/v_riding_18_04.mpg
# Processing 62.853%: /horse_riding/v_riding_18/v_riding_18_05.mpg
# Processing 62.982%: /horse_riding/v_riding_20/v_riding_20_08.mpg
# Processing 63.111%: /horse_riding/v_riding_20/v_riding_20_07.mpg
# Processing 63.239%: /horse_riding/v_riding_20/v_riding_20_02.mpg
# Processing 63.368%: /horse_riding/v_riding_20/v_riding_20_05.mpg
# Processing 63.496%: /horse_riding/v_riding_20/v_riding_20_06.mpg
# Processing 63.625%: /horse_riding/v_riding_20/v_riding_20_03.mpg
# Processing 63.753%: /horse_riding/v_riding_20/v_riding_20_01.mpg
# Processing 63.882%: /horse_riding/v_riding_20/v_riding_20_04.mpg
# Processing 64.01%: /horse_riding/v_riding_04/v_riding_04_08.mpg
# Processing 64.139%: /horse_riding/v_riding_04/v_riding_04_06.mpg
# Processing 64.267%: /horse_riding/v_riding_04/v_riding_04_04.mpg
# Processing 64.396%: /horse_riding/v_riding_04/v_riding_04_03.mpg
# Processing 64.524%: /horse_riding/v_riding_04/v_riding_04_02.mpg
# Processing 64.653%: /horse_riding/v_riding_04/v_riding_04_07.mpg
# Processing 64.781%: /horse_riding/v_riding_04/v_riding_04_01.mpg
# Processing 64.91%: /horse_riding/v_riding_04/v_riding_04_05.mpg
# Processing 65.039%: /horse_riding/v_riding_25/v_riding_25_22.mpg
# Processing 65.167%: /horse_riding/v_riding_25/v_riding_25_14.mpg
# Processing 65.296%: /horse_riding/v_riding_25/v_riding_25_10.mpg
# Processing 65.424%: /horse_riding/v_riding_25/v_riding_25_23.mpg
# Processing 65.553%: /horse_riding/v_riding_25/v_riding_25_08.mpg
# Processing 65.681%: /horse_riding/v_riding_25/v_riding_25_06.mpg
# Processing 65.81%: /horse_riding/v_riding_25/v_riding_25_17.mpg
# Processing 65.938%: /horse_riding/v_riding_25/v_riding_25_13.mpg
# Processing 66.067%: /horse_riding/v_riding_25/v_riding_25_18.mpg
# Processing 66.195%: /horse_riding/v_riding_25/v_riding_25_04.mpg
# Processing 66.324%: /horse_riding/v_riding_25/v_riding_25_02.mpg
# Processing 66.452%: /horse_riding/v_riding_25/v_riding_25_07.mpg
# Processing 66.581%: /horse_riding/v_riding_25/v_riding_25_11.mpg
# Processing 66.71%: /horse_riding/v_riding_25/v_riding_25_12.mpg
# Processing 66.838%: /horse_riding/v_riding_25/v_riding_25_19.mpg
# Processing 66.967%: /horse_riding/v_riding_25/v_riding_25_16.mpg
# Processing 67.095%: /horse_riding/v_riding_25/v_riding_25_03.mpg
# Processing 67.224%: /horse_riding/v_riding_25/v_riding_25_15.mpg
# Processing 67.352%: /horse_riding/v_riding_25/v_riding_25_20.mpg
# Processing 67.481%: /horse_riding/v_riding_25/v_riding_25_09.mpg
# Processing 67.609%: /horse_riding/v_riding_25/v_riding_25_05.mpg
# Processing 67.738%: /horse_riding/v_riding_25/v_riding_25_21.mpg
# Processing 67.866%: /horse_riding/v_riding_25/v_riding_25_01.mpg
# Processing 67.995%: /horse_riding/v_riding_10/v_riding_10_05.mpg
# Processing 68.123%: /horse_riding/v_riding_10/v_riding_10_08.mpg
# Processing 68.252%: /horse_riding/v_riding_10/v_riding_10_03.mpg
# Processing 68.38%: /horse_riding/v_riding_10/v_riding_10_01.mpg
# Processing 68.509%: /horse_riding/v_riding_10/v_riding_10_07.mpg
# Processing 68.638%: /horse_riding/v_riding_10/v_riding_10_04.mpg
# Processing 68.766%: /horse_riding/v_riding_10/v_riding_10_06.mpg
# Processing 68.895%: /horse_riding/v_riding_10/v_riding_10_02.mpg
# Processing 69.023%: /horse_riding/v_riding_16/v_riding_16_01.mpg
# Processing 69.152%: /horse_riding/v_riding_16/v_riding_16_03.mpg
# Processing 69.28%: /horse_riding/v_riding_16/v_riding_16_02.mpg
# Processing 69.409%: /horse_riding/v_riding_16/v_riding_16_04.mpg
# Processing 69.537%: /horse_riding/v_riding_16/v_riding_16_06.mpg
# Processing 69.666%: /horse_riding/v_riding_16/v_riding_16_05.mpg
# Processing 69.794%: /horse_riding/v_riding_01/v_riding_01_04.mpg
# Processing 69.923%: /horse_riding/v_riding_01/v_riding_01_06.mpg
# Processing 70.051%: /horse_riding/v_riding_01/v_riding_01_05.mpg
# Processing 70.18%: /horse_riding/v_riding_01/v_riding_01_07.mpg
# Processing 70.308%: /horse_riding/v_riding_01/v_riding_01_01.mpg
# Processing 70.437%: /horse_riding/v_riding_01/v_riding_01_09.mpg
# Processing 70.566%: /horse_riding/v_riding_01/v_riding_01_03.mpg
# Processing 70.694%: /horse_riding/v_riding_01/v_riding_01_02.mpg
# Processing 70.823%: /horse_riding/v_riding_01/v_riding_01_08.mpg
# Processing 70.951%: /horse_riding/v_riding_09/v_riding_09_06.mpg
# Processing 71.08%: /horse_riding/v_riding_09/v_riding_09_05.mpg
# Processing 71.208%: /horse_riding/v_riding_09/v_riding_09_01.mpg
# Processing 71.337%: /horse_riding/v_riding_09/v_riding_09_02.mpg
# Processing 71.465%: /horse_riding/v_riding_09/v_riding_09_03.mpg
# Processing 71.594%: /horse_riding/v_riding_09/v_riding_09_04.mpg
# Processing 71.722%: /horse_riding/v_riding_15/v_riding_15_03.mpg
# Processing 71.851%: /horse_riding/v_riding_15/v_riding_15_01.mpg
# Processing 71.979%: /horse_riding/v_riding_15/v_riding_15_06.mpg
# Processing 72.108%: /horse_riding/v_riding_15/v_riding_15_04.mpg
# Processing 72.237%: /horse_riding/v_riding_15/v_riding_15_05.mpg
# Processing 72.365%: /horse_riding/v_riding_15/v_riding_15_02.mpg
# Processing 72.494%: /horse_riding/v_riding_15/v_riding_15_07.mpg
# Processing 72.622%: /horse_riding/v_riding_06/v_riding_06_06.mpg
# Processing 72.751%: /horse_riding/v_riding_06/v_riding_06_05.mpg
# Processing 72.879%: /horse_riding/v_riding_06/v_riding_06_01.mpg
# Processing 73.008%: /horse_riding/v_riding_06/v_riding_06_04.mpg
# Processing 73.136%: /horse_riding/v_riding_06/v_riding_06_03.mpg
# Processing 73.265%: /horse_riding/v_riding_06/v_riding_06_07.mpg
# Processing 73.393%: /horse_riding/v_riding_06/v_riding_06_08.mpg
# Processing 73.522%: /horse_riding/v_riding_06/v_riding_06_09.mpg
# Processing 73.65%: /horse_riding/v_riding_06/v_riding_06_10.mpg
# Processing 73.779%: /horse_riding/v_riding_06/v_riding_06_02.mpg
# Processing 73.907%: /horse_riding/v_riding_17/v_riding_17_06.mpg
# Processing 74.036%: /horse_riding/v_riding_17/v_riding_17_01.mpg
# Processing 74.165%: /horse_riding/v_riding_17/v_riding_17_04.mpg
# Processing 74.293%: /horse_riding/v_riding_17/v_riding_17_02.mpg
# Processing 74.422%: /horse_riding/v_riding_17/v_riding_17_03.mpg
# Processing 74.55%: /horse_riding/v_riding_17/v_riding_17_05.mpg
# Processing 74.679%: /horse_riding/v_riding_03/v_riding_03_04.mpg
# Processing 74.807%: /horse_riding/v_riding_03/v_riding_03_07.mpg
# Processing 74.936%: /horse_riding/v_riding_03/v_riding_03_06.mpg
# Processing 75.064%: /horse_riding/v_riding_03/v_riding_03_01.mpg
# Processing 75.193%: /horse_riding/v_riding_03/v_riding_03_03.mpg
# Processing 75.321%: /horse_riding/v_riding_03/v_riding_03_02.mpg
# Processing 75.45%: /horse_riding/v_riding_03/v_riding_03_05.mpg
# Processing 75.578%: /horse_riding/v_riding_03/v_riding_03_08.mpg
# Processing 75.707%: /horse_riding/v_riding_24/v_riding_24_07.mpg
# Processing 75.835%: /horse_riding/v_riding_24/v_riding_24_08.mpg
# Processing 75.964%: /horse_riding/v_riding_24/v_riding_24_04.mpg
# Processing 76.093%: /horse_riding/v_riding_24/v_riding_24_03.mpg
# Processing 76.221%: /horse_riding/v_riding_24/v_riding_24_01.mpg
# Processing 76.35%: /horse_riding/v_riding_24/v_riding_24_02.mpg
# Processing 76.478%: /horse_riding/v_riding_24/v_riding_24_06.mpg
# Processing 76.607%: /horse_riding/v_riding_24/v_riding_24_05.mpg
# Processing 76.735%: /horse_riding/v_riding_07/v_riding_07_05.mpg
# Processing 76.864%: /horse_riding/v_riding_07/v_riding_07_08.mpg
# Processing 76.992%: /horse_riding/v_riding_07/v_riding_07_04.mpg
# Processing 77.121%: /horse_riding/v_riding_07/v_riding_07_01.mpg
# Processing 77.249%: /horse_riding/v_riding_07/v_riding_07_07.mpg
# Processing 77.378%: /horse_riding/v_riding_07/v_riding_07_06.mpg
# Processing 77.506%: /horse_riding/v_riding_07/v_riding_07_02.mpg
# Processing 77.635%: /horse_riding/v_riding_07/v_riding_07_03.mpg
# Processing 77.763%: /horse_riding/v_riding_19/v_riding_19_08.mpg
# Processing 77.892%: /horse_riding/v_riding_19/v_riding_19_06.mpg
# Processing 78.021%: /horse_riding/v_riding_19/v_riding_19_09.mpg
# Processing 78.149%: /horse_riding/v_riding_19/v_riding_19_04.mpg
# Processing 78.278%: /horse_riding/v_riding_19/v_riding_19_02.mpg
# Processing 78.406%: /horse_riding/v_riding_19/v_riding_19_03.mpg
# Processing 78.535%: /horse_riding/v_riding_19/v_riding_19_05.mpg
# Processing 78.663%: /horse_riding/v_riding_19/v_riding_19_07.mpg
# Processing 78.792%: /horse_riding/v_riding_19/v_riding_19_01.mpg
# Processing 78.92%: /horse_riding/v_riding_14/v_riding_14_06.mpg
# Processing 79.049%: /horse_riding/v_riding_14/v_riding_14_08.mpg
# Processing 79.177%: /horse_riding/v_riding_14/v_riding_14_01.mpg
# Processing 79.306%: /horse_riding/v_riding_14/v_riding_14_04.mpg
# Processing 79.434%: /horse_riding/v_riding_14/v_riding_14_02.mpg
# Processing 79.563%: /horse_riding/v_riding_14/v_riding_14_07.mpg
# Processing 79.692%: /horse_riding/v_riding_14/v_riding_14_05.mpg
# Processing 79.82%: /horse_riding/v_riding_14/v_riding_14_03.mpg
# Processing 79.949%: /diving/v_diving_03/v_diving_03_01.mpg
# Processing 80.077%: /diving/v_diving_03/v_diving_03_07.mpg
# Processing 80.206%: /diving/v_diving_03/v_diving_03_06.mpg
# Processing 80.334%: /diving/v_diving_03/v_diving_03_03.mpg
# Processing 80.463%: /diving/v_diving_03/v_diving_03_05.mpg
# Processing 80.591%: /diving/v_diving_03/v_diving_03_04.mpg
# Processing 80.72%: /diving/v_diving_03/v_diving_03_02.mpg
# Processing 80.848%: /diving/v_diving_03/v_diving_03_08.mpg
# Processing 80.977%: /diving/v_diving_16/v_diving_16_08.mpg
# Processing 81.105%: /diving/v_diving_16/v_diving_16_01.mpg
# Processing 81.234%: /diving/v_diving_16/v_diving_16_06.mpg
# Processing 81.362%: /diving/v_diving_16/v_diving_16_02.mpg
# Processing 81.491%: /diving/v_diving_16/v_diving_16_07.mpg
# Processing 81.62%: /diving/v_diving_16/v_diving_16_04.mpg
# Processing 81.748%: /diving/v_diving_16/v_diving_16_05.mpg
# Processing 81.877%: /diving/v_diving_16/v_diving_16_03.mpg
# Processing 82.005%: /diving/v_diving_15/v_diving_15_06.mpg
# Processing 82.134%: /diving/v_diving_15/v_diving_15_08.mpg
# Processing 82.262%: /diving/v_diving_15/v_diving_15_04.mpg
# Processing 82.391%: /diving/v_diving_15/v_diving_15_03.mpg
# Processing 82.519%: /diving/v_diving_15/v_diving_15_05.mpg
# Processing 82.648%: /diving/v_diving_15/v_diving_15_02.mpg
# Processing 82.776%: /diving/v_diving_15/v_diving_15_01.mpg
# Processing 82.905%: /diving/v_diving_15/v_diving_15_09.mpg
# Processing 83.033%: /diving/v_diving_15/v_diving_15_07.mpg
# Processing 83.162%: /diving/v_diving_12/v_diving_12_04.mpg
# Processing 83.29%: /diving/v_diving_12/v_diving_12_02.mpg
# Processing 83.419%: /diving/v_diving_12/v_diving_12_01.mpg
# Processing 83.548%: /diving/v_diving_12/v_diving_12_06.mpg
# Processing 83.676%: /diving/v_diving_12/v_diving_12_03.mpg
# Processing 83.805%: /diving/v_diving_12/v_diving_12_05.mpg
# Processing 83.933%: /diving/v_diving_12/v_diving_12_07.mpg
# Processing 84.062%: /diving/v_diving_06/v_diving_06_07.mpg
# Processing 84.19%: /diving/v_diving_06/v_diving_06_05.mpg
# Processing 84.319%: /diving/v_diving_06/v_diving_06_04.mpg
# Processing 84.447%: /diving/v_diving_06/v_diving_06_02.mpg
# Processing 84.576%: /diving/v_diving_06/v_diving_06_01.mpg
# Processing 84.704%: /diving/v_diving_06/v_diving_06_03.mpg
# Processing 84.833%: /diving/v_diving_06/v_diving_06_06.mpg
# Processing 84.961%: /diving/v_diving_08/v_diving_08_03.mpg
# Processing 85.09%: /diving/v_diving_08/v_diving_08_04.mpg
# Processing 85.219%: /diving/v_diving_08/v_diving_08_01.mpg
# Processing 85.347%: /diving/v_diving_08/v_diving_08_02.mpg
# Processing 85.476%: /diving/v_diving_08/v_diving_08_05.mpg
# Processing 85.604%: /diving/v_diving_08/v_diving_08_06.mpg
# Processing 85.733%: /diving/v_diving_17/v_diving_17_03.mpg
# Processing 85.861%: /diving/v_diving_17/v_diving_17_01.mpg
# Processing 85.99%: /diving/v_diving_17/v_diving_17_04.mpg
# Processing 86.118%: /diving/v_diving_17/v_diving_17_02.mpg
# Processing 86.247%: /diving/v_diving_13/v_diving_13_05.mpg
# Processing 86.375%: /diving/v_diving_13/v_diving_13_02.mpg
# Processing 86.504%: /diving/v_diving_13/v_diving_13_06.mpg
# Processing 86.632%: /diving/v_diving_13/v_diving_13_07.mpg
# Processing 86.761%: /diving/v_diving_13/v_diving_13_03.mpg
# Processing 86.889%: /diving/v_diving_13/v_diving_13_04.mpg
# Processing 87.018%: /diving/v_diving_13/v_diving_13_01.mpg
# Processing 87.147%: /diving/v_diving_11/v_diving_11_02.mpg
# Processing 87.275%: /diving/v_diving_11/v_diving_11_01.mpg
# Processing 87.404%: /diving/v_diving_11/v_diving_11_05.mpg
# Processing 87.532%: /diving/v_diving_11/v_diving_11_06.mpg
# Processing 87.661%: /diving/v_diving_11/v_diving_11_04.mpg
# Processing 87.789%: /diving/v_diving_11/v_diving_11_03.mpg
# Processing 87.918%: /diving/v_diving_22/v_diving_22_01.mpg
# Processing 88.046%: /diving/v_diving_22/v_diving_22_05.mpg
# Processing 88.175%: /diving/v_diving_22/v_diving_22_04.mpg
# Processing 88.303%: /diving/v_diving_22/v_diving_22_06.mpg
# Processing 88.432%: /diving/v_diving_22/v_diving_22_03.mpg
# Processing 88.56%: /diving/v_diving_22/v_diving_22_02.mpg
# Processing 88.689%: /diving/v_diving_19/v_diving_19_03.mpg
# Processing 88.817%: /diving/v_diving_19/v_diving_19_02.mpg
# Processing 88.946%: /diving/v_diving_19/v_diving_19_01.mpg
# Processing 89.075%: /diving/v_diving_19/v_diving_19_04.mpg
# Processing 89.203%: /diving/v_diving_07/v_diving_07_02.mpg
# Processing 89.332%: /diving/v_diving_07/v_diving_07_03.mpg
# Processing 89.46%: /diving/v_diving_07/v_diving_07_01.mpg
# Processing 89.589%: /diving/v_diving_07/v_diving_07_04.mpg
# Processing 89.717%: /diving/v_diving_25/v_diving_25_01.mpg
# Processing 89.846%: /diving/v_diving_25/v_diving_25_02.mpg
# Processing 89.974%: /diving/v_diving_25/v_diving_25_04.mpg
# Processing 90.103%: /diving/v_diving_25/v_diving_25_03.mpg
# Processing 90.231%: /diving/v_diving_01/v_diving_01_07.mpg
# Processing 90.36%: /diving/v_diving_01/v_diving_01_04.mpg
# Processing 90.488%: /diving/v_diving_01/v_diving_01_03.mpg
# Processing 90.617%: /diving/v_diving_01/v_diving_01_02.mpg
# Processing 90.746%: /diving/v_diving_01/v_diving_01_06.mpg
# Processing 90.874%: /diving/v_diving_01/v_diving_01_05.mpg
# Processing 91.003%: /diving/v_diving_01/v_diving_01_01.mpg
# Processing 91.131%: /diving/v_diving_09/v_diving_09_06.mpg
# Processing 91.26%: /diving/v_diving_09/v_diving_09_05.mpg
# Processing 91.388%: /diving/v_diving_09/v_diving_09_01.mpg
# Processing 91.517%: /diving/v_diving_09/v_diving_09_07.mpg
# Processing 91.645%: /diving/v_diving_09/v_diving_09_04.mpg
# Processing 91.774%: /diving/v_diving_09/v_diving_09_02.mpg
# Processing 91.902%: /diving/v_diving_09/v_diving_09_03.mpg
# Processing 92.031%: /diving/v_diving_20/v_diving_20_03.mpg
# Processing 92.159%: /diving/v_diving_20/v_diving_20_06.mpg
# Processing 92.288%: /diving/v_diving_20/v_diving_20_01.mpg
# Processing 92.416%: /diving/v_diving_20/v_diving_20_04.mpg
# Processing 92.545%: /diving/v_diving_20/v_diving_20_02.mpg
# Processing 92.674%: /diving/v_diving_20/v_diving_20_07.mpg
# Processing 92.802%: /diving/v_diving_20/v_diving_20_05.mpg
# Processing 92.931%: /diving/v_diving_02/v_diving_02_03.mpg
# Processing 93.059%: /diving/v_diving_02/v_diving_02_01.mpg
# Processing 93.188%: /diving/v_diving_02/v_diving_02_02.mpg
# Processing 93.316%: /diving/v_diving_02/v_diving_02_04.mpg
# Processing 93.445%: /diving/v_diving_02/v_diving_02_06.mpg
# Processing 93.573%: /diving/v_diving_02/v_diving_02_05.mpg
# Processing 93.702%: /diving/v_diving_02/v_diving_02_07.mpg
# Processing 93.83%: /diving/v_diving_05/v_diving_05_05.mpg
# Processing 93.959%: /diving/v_diving_05/v_diving_05_04.mpg
# Processing 94.087%: /diving/v_diving_05/v_diving_05_03.mpg
# Processing 94.216%: /diving/v_diving_05/v_diving_05_02.mpg
# Processing 94.344%: /diving/v_diving_05/v_diving_05_06.mpg
# Processing 94.473%: /diving/v_diving_05/v_diving_05_01.mpg
# Processing 94.602%: /diving/v_diving_10/v_diving_10_06.mpg
# Processing 94.73%: /diving/v_diving_10/v_diving_10_01.mpg
# Processing 94.859%: /diving/v_diving_10/v_diving_10_03.mpg
# Processing 94.987%: /diving/v_diving_10/v_diving_10_07.mpg
# Processing 95.116%: /diving/v_diving_10/v_diving_10_02.mpg
# Processing 95.244%: /diving/v_diving_10/v_diving_10_05.mpg
# Processing 95.373%: /diving/v_diving_10/v_diving_10_04.mpg
# Processing 95.501%: /diving/v_diving_04/v_diving_04_06.mpg
# Processing 95.63%: /diving/v_diving_04/v_diving_04_05.mpg
# Processing 95.758%: /diving/v_diving_04/v_diving_04_02.mpg
# Processing 95.887%: /diving/v_diving_04/v_diving_04_04.mpg
# Processing 96.015%: /diving/v_diving_04/v_diving_04_01.mpg
# Processing 96.144%: /diving/v_diving_04/v_diving_04_07.mpg
# Processing 96.272%: /diving/v_diving_04/v_diving_04_03.mpg
# Processing 96.401%: /diving/v_diving_23/v_diving_23_05.mpg
# Processing 96.53%: /diving/v_diving_23/v_diving_23_03.mpg
# Processing 96.658%: /diving/v_diving_23/v_diving_23_02.mpg
# Processing 96.787%: /diving/v_diving_23/v_diving_23_04.mpg
# Processing 96.915%: /diving/v_diving_23/v_diving_23_01.mpg
# Processing 97.044%: /diving/v_diving_23/v_diving_23_06.mpg
# Processing 97.172%: /diving/v_diving_24/v_diving_24_05.mpg
# Processing 97.301%: /diving/v_diving_24/v_diving_24_06.mpg
# Processing 97.429%: /diving/v_diving_24/v_diving_24_02.mpg
# Processing 97.558%: /diving/v_diving_24/v_diving_24_01.mpg
# Processing 97.686%: /diving/v_diving_24/v_diving_24_07.mpg
# Processing 97.815%: /diving/v_diving_24/v_diving_24_04.mpg
# Processing 97.943%: /diving/v_diving_24/v_diving_24_03.mpg
# Processing 98.072%: /diving/v_diving_14/v_diving_14_04.mpg
# Processing 98.201%: /diving/v_diving_14/v_diving_14_02.mpg
# Processing 98.329%: /diving/v_diving_14/v_diving_14_03.mpg
# Processing 98.458%: /diving/v_diving_14/v_diving_14_01.mpg
# Processing 98.586%: /diving/v_diving_21/v_diving_21_06.mpg
# Processing 98.715%: /diving/v_diving_21/v_diving_21_05.mpg
# Processing 98.843%: /diving/v_diving_21/v_diving_21_03.mpg
# Processing 98.972%: /diving/v_diving_21/v_diving_21_07.mpg
# Processing 99.1%: /diving/v_diving_21/v_diving_21_01.mpg
# Processing 99.229%: /diving/v_diving_21/v_diving_21_04.mpg
# Processing 99.357%: /diving/v_diving_21/v_diving_21_02.mpg
# Processing 99.486%: /diving/v_diving_18/v_diving_18_04.mpg
# Processing 99.614%: /diving/v_diving_18/v_diving_18_01.mpg
# Processing 99.743%: /diving/v_diving_18/v_diving_18_03.mpg
# Processing 99.871%: /diving/v_diving_18/v_diving_18_02.mpg
# Shape của videos: (775, 16, 64, 64, 3)
# Shape của labels: (775,)

# %%
print(data2.shape)
print(targets2.shape)
# Out:
# (775, 16, 64, 64, 3)
# (775,)

# %%
data2 = np.transpose(data2, (0, 4, 1, 2, 3))
data2.shape
# Out:
# (775, 3, 16, 64, 64)

# %%
print(data1.shape)
print(data2.shape)
# Out:
# (822, 3, 16, 64, 64)
# (775, 3, 16, 64, 64)

# %%
data = np.concatenate((data1, data2), axis=0)
targets = np.concatenate((targets1, targets2), axis=0)
print(data.shape)
print(targets.shape)

# %%
classes, counts = np.unique(targets, return_counts=True)

for class_id, count in zip(classes, counts):
    print(f"Class {class_id}: {count} samples")

# %%
class_counts = train_df['class'].value_counts()
print(class_counts)

# %%
class VideoNormalize:
    def __init__(self, mean, std):

        self.mean = torch.tensor(mean).view(1, -1, 1, 1, 1) 
        self.std = torch.tensor(std).view(1, -1, 1, 1, 1)

    def __call__(self, x):
        x = x.float()
        return (x - self.mean) / self.std

# %%
mean = [0.485, 0.456, 0.406]
std = [0.229, 0.224, 0.225]

class ScaleTransform:
    def __call__(self, x):
        return x / 255.0
transform = transforms.Compose([
    ScaleTransform(),
    transforms.RandomHorizontalFlip(p=0.3) 
])

# %%
X_train, X_test, y_train, y_test = train_test_split(data, targets, shuffle=True, test_size = 0.2, random_state = 42, stratify= targets)

# %%
print(2)
train_dataset = PrepareData(X_train, y_train, transform=transform)
test_dataset = PrepareData(X_test, y_test, transform=transform)
print(1)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)
# Out:
# 2
# 1

# %% [markdown]
# # Load Dataset

# %% [markdown]
# *Run from here*****

# %%
# import torch
# torch.save(train_dataset, '/kaggle/working/train_dataset.pt')
# torch.save(test_dataset, '/kaggle/working/test_dataset.pt')

# %%
data, target = next(iter(train_loader))

print("Data shape:", data.shape)
print("Target shape:", target.shape)
# Out:
# Data shape: torch.Size([16, 3, 16, 64, 64])
# Target shape: torch.Size([16])

# %% [markdown]
# # Create Model

# %%
class Conv3D(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(Conv3D, self).__init__()
        self.conv = nn.Conv3d(in_channels=in_channels, out_channels=out_channels, kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=(0, 1, 1), bias=False)
        self.bn = nn.BatchNorm3d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv(x)
        x = self.bn(x)
        x = self.relu(x)
        return x

# %%
class ResBlock3D(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels, stride=1):
        super(ResBlock3D, self).__init__()
        self.conv1 = nn.Conv3d(in_channels, mid_channels, kernel_size=(1, 1, 1), stride=1, bias=False)
        self.bn1 = nn.BatchNorm3d(mid_channels)
        self.conv2 = nn.Conv3d(mid_channels, mid_channels, kernel_size=(3, 3, 3), stride=stride, padding=(1, 1, 1), bias=False)
        self.bn2 = nn.BatchNorm3d(mid_channels)
        self.conv3 = nn.Conv3d(mid_channels, out_channels, kernel_size=(1, 1, 1), stride=1, bias=False)
        self.bn3 = nn.BatchNorm3d(out_channels)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv3d(in_channels, out_channels, kernel_size=(1, 1, 1), stride=stride, bias=False),
                nn.BatchNorm3d(out_channels)
            )
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out

# %%
class Bottleneck3D(nn.Module):
    def __init__(self, in_channels, mid_channels, out_channels, stride=1):
        super(Bottleneck3D, self).__init__()
        self.conv1 = nn.Conv3d(in_channels, mid_channels, kernel_size=1, stride=1, bias=False)
        self.bn1 = nn.BatchNorm3d(mid_channels)
        self.conv2 = nn.Conv3d(mid_channels, mid_channels, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm3d(mid_channels)
        self.conv3 = nn.Conv3d(mid_channels, out_channels, kernel_size=1, stride=1, bias=False)
        self.bn3 = nn.BatchNorm3d(out_channels)
        self.relu = nn.ReLU(inplace=True)

        self.downsample = None
        if stride != 1 or in_channels != out_channels:
            self.downsample = nn.Sequential(
                nn.Conv3d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm3d(out_channels)
            )

    def forward(self, x):
        identity = x
        if self.downsample is not None:
            identity = self.downsample(x)

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)
        out = self.conv2(out)
        out = self.bn2(out)
        out = self.relu(out)
        out = self.conv3(out)
        out = self.bn3(out)
        out += identity
        out = self.relu(out)
        return out

# %%
class SEBlock3D(nn.Module):
    def __init__(self, channels, reduction=16):
        super(SEBlock3D, self).__init__()
        self.fc1 = nn.Linear(channels, channels // reduction)
        self.fc2 = nn.Linear(channels // reduction, channels)

    def forward(self, x):
        B, C, T, H, W = x.size()
        y = x.mean(dim=(2, 3, 4))  
        y = torch.relu(self.fc1(y))
        y = torch.sigmoid(self.fc2(y))
        y = y.view(B, C, 1, 1, 1)
        return x * y

# %%
class BottleneckWithSE3D(Bottleneck3D):
    def __init__(self, in_channels, mid_channels, out_channels, stride=1):
        super().__init__(in_channels, mid_channels, out_channels, stride)
        self.se = SEBlock3D(out_channels)

    def forward(self, x):
        out = super().forward(x)
        out = self.se(out)
        return out

# %%
class Res1(nn.Module): # base model
    def __init__(self):
        super(Res1, self).__init__()
        self.layer = self._make_layer(in_channels=32, mid_channels=72, out_channels=162, num_blocks=5, stride=2)

    def _make_layer(self, in_channels, mid_channels, out_channels, num_blocks, stride):
        layers = []
        for i in range(num_blocks):
            if i == 0:
                layers.append(ResBlock3D(in_channels, mid_channels, out_channels, stride))
            else:
                layers.append(ResBlock3D(out_channels, mid_channels, out_channels, stride=1))
        return nn.Sequential(*layers)
    def forward(self, x):
        return self.layer(x)
class Res2(nn.Module):
    def __init__(self):
        super(Res2, self).__init__()
        self.layer = self._make_layer(in_channels=32, mid_channels=80, out_channels=200, num_blocks=10, stride=2)

    def _make_layer(self, in_channels, mid_channels, out_channels, num_blocks, stride):
        layers = []
        for i in range(num_blocks):
            if i == 0:
                layers.append(ResBlock3D(in_channels, mid_channels, out_channels, stride))
            else:
                layers.append(ResBlock3D(out_channels, mid_channels, out_channels, stride=1))
        return nn.Sequential(*layers)

    def forward(self, x):
        return self.layer(x)
class Res3(nn.Module):
    def __init__(self):
        super(Res3, self).__init__()
        self.layer = self._make_layer(in_channels=32, mid_channels=64, out_channels=128, num_blocks=5, stride=2)

    def _make_layer(self, in_channels, mid_channels, out_channels, num_blocks, stride):
        layers = []
        for i in range(num_blocks):
            if i == 0:
                layers.append(ResBlock3D(in_channels, mid_channels, out_channels, stride))
            else:
                layers.append(ResBlock3D(out_channels, mid_channels, out_channels, stride=1))
        return nn.Sequential(*layers)
    def forward(self, x):
        return self.layer(x)
class Res4(nn.Module):
    def __init__(self):
        super(Res4, self).__init__()
        self.layer = self._make_layer(in_channels=32, mid_channels=72, out_channels=162, num_blocks=5, stride=2)

    def _make_layer(self, in_channels, mid_channels, out_channels, num_blocks, stride):
        layers = []
        for i in range(num_blocks):
            if i == 0:
                layers.append(BottleneckWithSE3D(in_channels, mid_channels, out_channels, stride))
            else:
                layers.append(BottleneckWithSE3D(out_channels, mid_channels, out_channels, stride=1))
        return nn.Sequential(*layers)

    def forward(self, x):
        return self.layer(x)

# %%
class ChannelWise3D(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(ChannelWise3D, self).__init__()
        self.conv3d = nn.Conv3d(  in_channels=in_channels,out_channels=out_channels,kernel_size=(1, 1, 1), stride=(1, 1, 1),    padding=(0, 0, 0),    bias=False)
        self.bn = nn.BatchNorm3d(out_channels)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.conv3d(x)
        x = self.bn(x)
        x = self.relu(x)
        return x

# %%
class DL_Project7(nn.Module):
    def __init__(self, num_classes):
        super(DL_Project7, self).__init__()
        self.conv1 = Conv3D(in_channels=3, out_channels=32) 
        self.res1 = Res4() # change to Res1(), Res2(), Res3() if you want to test
        self.conv2 = ChannelWise3D(in_channels=162, out_channels=128)
        self.globalaveragepooling = nn.AdaptiveAvgPool3d(1) 
        self.fc1 = nn.Linear(in_features=128, out_features=64) 
        self.fc2 = nn.Linear(in_features=64, out_features=num_classes)
     
        self.dropout2 = nn.Dropout(p=0.5) 
    def forward(self, x):
        x = self.conv1(x)
        x = self.res1(x) 
        x = self.conv2(x)
        x = self.globalaveragepooling(x) 
        x = x.view(x.size(0), -1) 
       

        x = self.fc1(x) 
        x = self.dropout2(x)
        x = self.fc2(x)
        return x

# %%
model = DL_Project7(NUM_CLASSES)

# %% [markdown]
# # Check output

# %%
b, seq_len, c, h, w = 8, 3, 16, 64,64  
input_tensor = torch.randn(b, seq_len, c, h, w)

print("Input shape:", input_tensor.shape)

output = model(input_tensor)
print("Output shape:", output.shape)
# Out:
# Input shape: torch.Size([8, 3, 16, 64, 64])
# Output shape: torch.Size([8, 11])

# %%
NUM_EPOCHS = 50
LEARNING_RATE = 0.0001
CHECKPOINT_PATH = "/kaggle/working/model.pth"
project = "Project_DL"
resume = 'allow'
class_weights = torch.tensor([2.5 if i in [0, 3] else 1.0 for i in range(NUM_CLASSES)], dtype=torch.float32).to(DEVICE)
loss_fn = nn.CrossEntropyLoss(
    weight=class_weights.clone().detach(),
    label_smoothing=0.1
)
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE,weight_decay= 0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=4)
scheduler2 = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# %%
wandb.finish()
# Out:
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>learning_rate</td><td>███████████████████▄▄▄▄▄▃▃▃▃▃▃▃▂▂▂▂▁▁▁▁▁</td></tr><tr><td>train_accuracy</td><td>▁▂▃▃▃▄▄▅▅▅▆▆▆▆▆▆▇▇▇▇▇███████████████████</td></tr><tr><td>train_loss</td><td>█▇▆▆▅▅▅▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▄▅▅▅▆▆▆▆▆▇▇▇▆▇▇▆▇▇████████████████████</td></tr><tr><td>val_loss</td><td>█▅▄▄▃▄▂▂▂▂▂▂▂▂▁▁▂▂▂▁▁▁▁▂▂▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>50</td></tr><tr><td>learning_rate</td><td>0.0</td></tr><tr><td>train_accuracy</td><td>99.13861</td></tr><tr><td>train_loss</td><td>0.63761</td></tr><tr><td>val_accuracy</td><td>85</td></tr><tr><td>val_loss</td><td>1.08151</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">Project_DL_model_9</strong> at: <a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/9ktmipdx' target="_blank">https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/9ktmipdx</a><br/> View project at: <a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL' target="_blank">https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20241210_035518-9ktmipdx/logs</code>

# %%
wandb.init(
    project=project,
    resume= resume,
    config={
        "learning_rate": LEARNING_RATE,
        "epochs": NUM_EPOCHS,
        "batch_size": BATCH_SIZE,
    },
    name="Project_DL_model_9"
)
# Out:
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/kaggle/working/wandb/run-20241210_042313-sf1mvb4x</code>
# Syncing run <strong><a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/sf1mvb4x' target="_blank">Project_DL_model_9</a></strong> to <a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL' target="_blank">https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL</a>
#  View run at <a href='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/sf1mvb4x' target="_blank">https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/sf1mvb4x</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/nguyenhoangson_hsgs19-hanoi-university-of-science-and-te/Project_DL/runs/sf1mvb4x?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def train_and_validate(model, train_loader, val_loader, optimizer, criterion, scheduler, epochs):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    
    best_val_loss = float('inf') 
    model = model.to(DEVICE)
    for epoch in range(epochs):
        print(sum(p.numel() for p in model.parameters()))
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        
        # Training loop
        for images, labels in train_loader:
            images, labels = images.to(DEVICE), labels.to(DEVICE).long()  
            optimizer.zero_grad() 
            outputs = model(images) 
            loss = criterion(outputs, labels)  
            loss.backward() 
            optimizer.step()  
            running_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        train_loss = running_loss / len(train_loader)
        train_accuracy = 100 * correct / total
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        # Validation loop
        model.eval()
        val_running_loss = 0.0
        val_correct = 0
        val_total = 0
        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(DEVICE), labels.to(DEVICE).long()
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_running_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

        val_loss = val_running_loss / len(val_loader)
        val_accuracy = 100 * val_correct / val_total
        val_losses.append(val_loss)
        val_accuracies.append(val_accuracy)

        scheduler.step(val_loss) # cho scheduler
        # scheduler.step() # cho scheduler2

        wandb.log({
            "epoch": epoch + 1,
            "train_loss": train_loss,
            "train_accuracy": train_accuracy,
            "val_loss": val_loss,
            "val_accuracy": val_accuracy,
            "learning_rate": optimizer.param_groups[0]["lr"]
        })

        
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(),"model.pth")
            wandb.save("model.pth")

        print(f"Epoch [{epoch + 1}/{epochs}]")
        print(f"    Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.2f}%")
        print(f"    Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%")

    return train_losses, val_losses, train_accuracies, val_accuracies

# %% [markdown]
# # Train Model

# %%
train_and_validate(model, train_loader, test_loader, optimizer, loss_fn, scheduler, NUM_EPOCHS)
# Out:
# 863639
# Epoch [1/50]
#     Train Loss: 2.2372, Train Accuracy: 19.03%
#     Val Loss: 2.3757, Val Accuracy: 13.75%
# 863639
# Epoch [2/50]
#     Train Loss: 2.0241, Train Accuracy: 27.80%
#     Val Loss: 1.8762, Val Accuracy: 38.12%
# 863639
# Epoch [3/50]
#     Train Loss: 1.8819, Train Accuracy: 34.14%
#     Val Loss: 1.8235, Val Accuracy: 44.69%
# 863639
# Epoch [4/50]
#     Train Loss: 1.7518, Train Accuracy: 40.64%
#     Val Loss: 1.5424, Val Accuracy: 50.00%
# 863639
# Epoch [5/50]
#     Train Loss: 1.6748, Train Accuracy: 46.44%
#     Val Loss: 1.5193, Val Accuracy: 52.50%
# 863639
# Epoch [6/50]
#     Train Loss: 1.5956, Train Accuracy: 48.47%
#     Val Loss: 1.3993, Val Accuracy: 56.88%
# 863639
# Epoch [7/50]
#     Train Loss: 1.5582, Train Accuracy: 51.53%
#     Val Loss: 1.4091, Val Accuracy: 54.06%
# 863639
# Epoch [8/50]
#     Train Loss: 1.4564, Train Accuracy: 57.17%
#     Val Loss: 1.3989, Val Accuracy: 58.44%
# 863639
# Epoch [9/50]
#     Train Loss: 1.4367, Train Accuracy: 56.15%
#     Val Loss: 1.3741, Val Accuracy: 58.44%
# 863639
# Epoch [10/50]
#     Train Loss: 1.3899, Train Accuracy: 58.81%
#     Val Loss: 1.3591, Val Accuracy: 69.06%
# 863639
# Epoch [11/50]
#     Train Loss: 1.3595, Train Accuracy: 60.30%
#     Val Loss: 1.4964, Val Accuracy: 60.00%
# 863639
# Epoch [12/50]
#     Train Loss: 1.2741, Train Accuracy: 64.60%
#     Val Loss: 1.4132, Val Accuracy: 56.88%
# 863639
# Epoch [13/50]
#     Train Loss: 1.2256, Train Accuracy: 68.13%
#     Val Loss: 1.4707, Val Accuracy: 55.31%
# 863639
# Epoch [14/50]
#     Train Loss: 1.1848, Train Accuracy: 68.68%
#     Val Loss: 1.1780, Val Accuracy: 72.50%
# 863639
# Epoch [15/50]
#     Train Loss: 1.1655, Train Accuracy: 71.10%
#     Val Loss: 1.1730, Val Accuracy: 69.69%
# 863639
# Epoch [16/50]
#     Train Loss: 1.1031, Train Accuracy: 74.78%
#     Val Loss: 1.3779, Val Accuracy: 64.69%
# 863639
# Epoch [17/50]
#     Train Loss: 1.0322, Train Accuracy: 79.56%
#     Val Loss: 1.0955, Val Accuracy: 74.69%
# 863639
# Epoch [18/50]
#     Train Loss: 1.0423, Train Accuracy: 79.56%
#     Val Loss: 1.1399, Val Accuracy: 70.31%
# 863639
# Epoch [19/50]
#     Train Loss: 0.9835, Train Accuracy: 80.27%
#     Val Loss: 1.1686, Val Accuracy: 72.19%
# 863639
# Epoch [20/50]
#     Train Loss: 0.9882, Train Accuracy: 79.80%
#     Val Loss: 1.3824, Val Accuracy: 71.25%
# 863639
# Epoch [21/50]
#     Train Loss: 0.9601, Train Accuracy: 82.38%
#     Val Loss: 1.0597, Val Accuracy: 80.31%
# 863639
# Epoch [22/50]
#     Train Loss: 0.9113, Train Accuracy: 84.34%
#     Val Loss: 1.0986, Val Accuracy: 76.56%
# 863639
# Epoch [23/50]
#     Train Loss: 0.9082, Train Accuracy: 85.20%
#     Val Loss: 1.3236, Val Accuracy: 75.00%
# 863639
# Epoch [24/50]
#     Train Loss: 0.8945, Train Accuracy: 86.14%
#     Val Loss: 1.0412, Val Accuracy: 78.75%
# 863639
# Epoch [25/50]
#     Train Loss: 0.8712, Train Accuracy: 87.55%
#     Val Loss: 1.2127, Val Accuracy: 76.88%
# 863639
# Epoch [26/50]
#     Train Loss: 0.8461, Train Accuracy: 88.88%
#     Val Loss: 1.4392, Val Accuracy: 65.31%
# 863639
# Epoch [27/50]
#     Train Loss: 0.8182, Train Accuracy: 89.74%
#     Val Loss: 0.9664, Val Accuracy: 86.56%
# 863639
# Epoch [28/50]
#     Train Loss: 0.7599, Train Accuracy: 93.74%
#     Val Loss: 0.9900, Val Accuracy: 84.06%
# 863639
# Epoch [29/50]
#     Train Loss: 0.7802, Train Accuracy: 92.40%
#     Val Loss: 0.9603, Val Accuracy: 85.62%
# 863639
# Epoch [30/50]
#     Train Loss: 0.7514, Train Accuracy: 92.87%
#     Val Loss: 1.4433, Val Accuracy: 72.50%
# 863639
# Epoch [31/50]
#     Train Loss: 0.7364, Train Accuracy: 93.81%
#     Val Loss: 1.1221, Val Accuracy: 82.50%
# 863639
# Epoch [32/50]
#     Train Loss: 0.7654, Train Accuracy: 92.80%
#     Val Loss: 0.9945, Val Accuracy: 83.75%
# 863639
# Epoch [33/50]
#     Train Loss: 0.7542, Train Accuracy: 93.19%
#     Val Loss: 0.9667, Val Accuracy: 84.69%
# 863639
# Epoch [34/50]
#     Train Loss: 0.7311, Train Accuracy: 94.13%
#     Val Loss: 1.0087, Val Accuracy: 84.38%
# 863639
# Epoch [35/50]
#     Train Loss: 0.7080, Train Accuracy: 95.69%
#     Val Loss: 0.9411, Val Accuracy: 86.88%
# 863639
# Epoch [36/50]
#     Train Loss: 0.6806, Train Accuracy: 96.95%
#     Val Loss: 0.9378, Val Accuracy: 87.19%
# 863639
# Epoch [37/50]
#     Train Loss: 0.6455, Train Accuracy: 98.20%
#     Val Loss: 0.9382, Val Accuracy: 87.50%
# 863639
# Epoch [38/50]
#     Train Loss: 0.6644, Train Accuracy: 96.79%
#     Val Loss: 0.9754, Val Accuracy: 83.44%
# 863639
# Epoch [39/50]
#     Train Loss: 0.6493, Train Accuracy: 98.43%
#     Val Loss: 0.8885, Val Accuracy: 87.19%
# 863639
# Epoch [40/50]
#     Train Loss: 0.6563, Train Accuracy: 98.20%
#     Val Loss: 0.9436, Val Accuracy: 86.25%
# 863639
# Epoch [41/50]
#     Train Loss: 0.6442, Train Accuracy: 98.51%
#     Val Loss: 0.9396, Val Accuracy: 87.81%
# 863639
# Epoch [42/50]
#     Train Loss: 0.6303, Train Accuracy: 98.90%
#     Val Loss: 0.8773, Val Accuracy: 87.19%
# 863639
# Epoch [43/50]
#     Train Loss: 0.6444, Train Accuracy: 98.04%
#     Val Loss: 0.9808, Val Accuracy: 86.56%
# 863639
# Epoch [44/50]
#     Train Loss: 0.6406, Train Accuracy: 98.59%
#     Val Loss: 0.9106, Val Accuracy: 86.25%
# 863639
# Epoch [45/50]
#     Train Loss: 0.6339, Train Accuracy: 98.20%
#     Val Loss: 0.8952, Val Accuracy: 88.44%
# 863639
# Epoch [46/50]
#     Train Loss: 0.6387, Train Accuracy: 98.67%
#     Val Loss: 0.8985, Val Accuracy: 87.50%
# 863639
# Epoch [47/50]
#     Train Loss: 0.6381, Train Accuracy: 98.67%
#     Val Loss: 0.8736, Val Accuracy: 89.69%
# 863639
# Epoch [48/50]
#     Train Loss: 0.6299, Train Accuracy: 98.51%
#     Val Loss: 1.0489, Val Accuracy: 84.69%
# 863639
# Epoch [49/50]
#     Train Loss: 0.6308, Train Accuracy: 98.59%
#     Val Loss: 0.9540, Val Accuracy: 85.00%
# 863639
# Epoch [50/50]
#     Train Loss: 0.6311, Train Accuracy: 98.43%
#     Val Loss: 0.9017, Val Accuracy: 88.12%
# ([2.2372146040201186,
#   2.0240764051675795,
#   1.881879797577858,
#   1.7517979711294174,
#   1.6748097971081735,
#   1.5956433773040772,
#   1.5581915453076363,
#   1.4563925981521606,
#   1.4366832822561264,
#   1.3898507088422776,
#   1.359531431645155,
#   1.274062331020832,
#   1.2256345458328723,
#   1.1847680047154427,
#   1.1655121803283692,
#   1.1031337812542916,
#   1.0321773804724217,
#   1.0423201702535152,
#   0.9835062317550183,
#   0.9881703376770019,
#   0.9600533574819565,
#   0.9112992726266385,
#   0.9081620424985886,
#   0.8945342361927032,
#   0.871157082170248,
#   0.8461157143115997,
#   0.8182184092700482,
#   0.7598855376243592,
#   0.7802198581397534,
#   0.7513516798615456,
#   0.7364035062491894,
#   0.7654045417904853,
#   0.7541856452822685,
#   0.7311099246144295,
#   0.7079723540693521,
#   0.6806116320192814,
#   0.6455041497945786,
#   0.664447533339262,
#   0.6492742396891117,
#   0.6562551192939281,
#   0.6442303784191609,
#   0.6302946213632822,
#   0.6443831607699394,
#   0.6405522886663675,
#   0.6339060012251139,
#   0.6386844284832478,
#   0.6381347358226777,
#   0.6299054007977247,
#   0.6307527594268322,
#   0.6311338394880295],
#  [2.3757235527038576,
#   1.8762173116207124,
#   1.823531574010849,
#   1.542366087436676,
#   1.5193310916423797,
#   1.3993216514587403,
#   1.4091275811195374,
#   1.39887775182724,
#   1.3740748703479766,
#   1.359104472398758,
#   1.4963949143886566,
#   1.413200968503952,
#   1.4706837713718415,
#   1.178031972050667,
#   1.173033246397972,
#   1.377859365940094,
#   1.0955472767353058,
#   1.139862710237503,
#   1.1686060339212418,
#   1.3824002265930175,
#   1.0597459137439729,
#   1.098640313744545,
#   1.323584708571434,
#   1.0412114620208741,
#   1.2127460330724715,
#   1.4392433732748031,
#   0.9664129167795181,
#   0.990002590417862,
#   0.9602515637874603,
#   1.443293684720993,
#   1.1221004366874694,
#   0.9945019215345383,
#   0.9666995346546173,
#   1.0087149113416671,
#   0.9411476194858551,
#   0.9377537280321121,
#   0.9382417947053909,
#   0.9754400283098221,
#   0.8884743571281433,
#   0.9436011970043182,
#   0.9395709782838821,
#   0.87726309299469,
#   0.9807985097169876,
#   0.9105902969837188,
#   0.8951676428318024,
#   0.8984602510929107,
#   0.8735801398754119,
#   1.0489478707313538,
#   0.9540004402399063,
#   0.9017045378684998],
#  [19.028974158183242,
#   27.799530148786218,
#   34.1425215348473,
#   40.642129992169146,
#   46.43696162881754,
#   48.47298355520752,
#   51.52701644479248,
#   57.16523101018011,
#   56.14722004698512,
#   58.809710258418164,
#   60.29757243539546,
#   64.60454189506656,
#   68.12842599843383,
#   68.67658574784652,
#   71.10415035238842,
#   74.78465152701645,
#   79.56147220046985,
#   79.56147220046985,
#   80.26624902114331,
#   79.796397807361,
#   82.38057948316367,
#   84.33829287392325,
#   85.19968676585748,
#   86.13938919342208,
#   87.548942834769,
#   88.88018794048551,
#   89.74158183241974,
#   93.7353171495693,
#   92.40407204385278,
#   92.87392325763508,
#   93.81362568519968,
#   92.7956147220047,
#   93.18715740015662,
#   94.12685982772122,
#   95.69303054032889,
#   96.94596711041504,
#   98.19890368050118,
#   96.78935003915427,
#   98.43382928739233,
#   98.19890368050118,
#   98.51213782302271,
#   98.90368050117463,
#   98.0422866092404,
#   98.5904463586531,
#   98.19890368050118,
#   98.66875489428348,
#   98.66875489428348,
#   98.51213782302271,
#   98.5904463586531,
#   98.43382928739233],
#  [13.75,
#   38.125,
#   44.6875,
#   50.0,
#   52.5,
#   56.875,
#   54.0625,
#   58.4375,
#   58.4375,
#   69.0625,
#   60.0,
#   56.875,
#   55.3125,
#   72.5,
#   69.6875,
#   64.6875,
#   74.6875,
#   70.3125,
#   72.1875,
#   71.25,
#   80.3125,
#   76.5625,
#   75.0,
#   78.75,
#   76.875,
#   65.3125,
#   86.5625,
#   84.0625,
#   85.625,
#   72.5,
#   82.5,
#   83.75,
#   84.6875,
#   84.375,
#   86.875,
#   87.1875,
#   87.5,
#   83.4375,
#   87.1875,
#   86.25,
#   87.8125,
#   87.1875,
#   86.5625,
#   86.25,
#   88.4375,
#   87.5,
#   89.6875,
#   84.6875,
#   85.0,
#   88.125])
